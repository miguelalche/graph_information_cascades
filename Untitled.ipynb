# %% [markdown]
# # Information Cascades en Grafos

# %%
import pandas as pd
import numpy as np

# %%
filename = "./results.csv"
def wipeResults(filename):
    f = open(filename,"w+")
    f.write("Graph type;Number of nodes;Edge chance;Opinions affected by Cascade;Opinions Changed by Cascade\n")

# %%
repetitions = 10
for i in range(repetitions):
    # !node index $filename
# Out:
# BLUE URN
# ./results.csv
# Node : 0 sees blue
# Looking at his neighbours sees {}
# mantained his decision:  blue
# Node 0 decides:  blue
#
# Node : 1 sees red
# Looking at his neighbours sees {}
# mantained his decision:  red
# Node 1 decides:  red
#
# Node : 2 sees blue
# Looking at his neighbours sees {}
# mantained his decision:  blue
# Node 2 decides:  blue
#
# Node : 3 sees blue
# Looking at his neighbours sees {}
# mantained his decision:  blue
# Node 3 decides:  blue
#
# Node : 4 sees blue
# Looking at his neighbours sees { blue: 1 }
# mantained his decision:  blue
# Node 4 decides:  blue
#
# Node : 5 sees blue
# Looking at his neighbours sees { blue: 1 }
# mantained his decision:  blue
# Node 5 decides:  blue
#
# Node : 6 sees red
# Looking at his neighbours sees { blue: 3, red: 1 }
# it has been influenced towards:  blue
# Node 6 decides:  blue
#
# Node : 7 sees blue
# Looking at his neighbours sees { blue: 1 }
# mantained his decision:  blue
# Node 7 decides:  blue
#
# Node : 8 sees red
# Looking at his neighbours sees { red: 1, blue: 2 }
# mantained his decision:  red
# Node 8 decides:  red
#
# Node : 9 sees blue
# Looking at his neighbours sees { blue: 2, red: 1 }
# mantained his decision:  blue
# Node 9 decides:  blue
#
# Node : 10 sees blue
# Looking at his neighbours sees { blue: 1 }
# mantained his decision:  blue
# Node 10 decides:  blue
#
# Node : 11 sees red
# Looking at his neighbours sees { blue: 2 }
# it has been influenced towards:  blue
# Node 11 decides:  blue
#
# Node : 12 sees blue
# Looking at his neighbours sees { blue: 4, red: 1 }
# mantained his decision:  blue
# Node 12 decides:  blue
#
# Node : 13 sees blue
# Looking at his neighbours sees { blue: 4, red: 1 }
# mantained his decision:  blue
# Node 13 decides:  blue
#
# Node : 14 sees blue
# Looking at his neighbours sees { blue: 4, red: 1 }
# mantained his decision:  blue
# Node 14 decides:  blue
#
# Node : 15 sees blue
# Looking at his neighbours sees { blue: 6, red: 1 }
# mantained his decision:  blue
# Node 15 decides:  blue
#
# Node : 16 sees blue
# Looking at his neighbours sees { blue: 4, red: 1 }
# mantained his decision:  blue
# Node 16 decides:  blue
#
# Node : 17 sees blue
# Looking at his neighbours sees { blue: 5, red: 2 }
# mantained his decision:  blue
# Node 17 decides:  blue
#
# Node : 18 sees blue
# Looking at his neighbours sees { blue: 5, red: 1 }
# mantained his decision:  blue
# Node 18 decides:  blue
#
# Node : 19 sees red
# Looking at his neighbours sees { blue: 6 }
# it has been influenced towards:  blue
# Node 19 decides:  blue
#
# Node : 20 sees blue
# Looking at his neighbours sees { blue: 4 }
# mantained his decision:  blue
# Node 20 decides:  blue
#
# Node : 21 sees blue
# Looking at his neighbours sees { blue: 2 }
# mantained his decision:  blue
# Node 21 decides:  blue
#
# Node : 22 sees blue
# Looking at his neighbours sees { blue: 8, red: 1 }
# mantained his decision:  blue
# Node 22 decides:  blue
#
# Node : 23 sees blue
# Looking at his neighbours sees { red: 1, blue: 5 }
# mantained his decision:  blue
# Node 23 decides:  blue
#
# Node : 24 sees red
# Looking at his neighbours sees { blue: 9 }
# it has been influenced towards:  blue
# Node 24 decides:  blue
#
# Node : 25 sees blue
# Looking at his neighbours sees { blue: 12 }
# mantained his decision:  blue
# Node 25 decides:  blue
#
# Node : 26 sees red
# Looking at his neighbours sees { blue: 8 }
# it has been influenced towards:  blue
# Node 26 decides:  blue
#
# Node : 27 sees blue
# Looking at his neighbours sees { blue: 9, red: 2 }
# mantained his decision:  blue
# Node 27 decides:  blue
#
# Node : 28 sees blue
# Looking at his neighbours sees { red: 1, blue: 11 }
# mantained his decision:  blue
# Node 28 decides:  blue
#
# Node : 29 sees red
# Looking at his neighbours sees { red: 2, blue: 6 }
# it has been influenced towards:  blue
# Node 29 decides:  blue
#
# Node : 30 sees red
# Looking at his neighbours sees { blue: 7 }
# it has been influenced towards:  blue
# Node 30 decides:  blue
#
# Node : 31 sees blue
# Looking at his neighbours sees { blue: 6, red: 1 }
# mantained his decision:  blue
# Node 31 decides:  blue
#
# Node : 32 sees red
# Looking at his neighbours sees { blue: 9 }
# it has been influenced towards:  blue
# Node 32 decides:  blue
#
# Node : 33 sees red
# Looking at his neighbours sees { blue: 14, red: 1 }
# it has been influenced towards:  blue
# Node 33 decides:  blue
#
# Node : 34 sees blue
# Looking at his neighbours sees { red: 1, blue: 4 }
# mantained his decision:  blue
# Node 34 decides:  blue
#
# Node : 35 sees blue
# Looking at his neighbours sees { blue: 13 }
# mantained his decision:  blue
# Node 35 decides:  blue
#
# Node : 36 sees blue
# Looking at his neighbours sees { blue: 13 }
# mantained his decision:  blue
# Node 36 decides:  blue
#
# Node : 37 sees blue
# Looking at his neighbours sees { red: 2, blue: 10 }
# mantained his decision:  blue
# Node 37 decides:  blue
#
# Node : 38 sees red
# Looking at his neighbours sees { blue: 8 }
# it has been influenced towards:  blue
# Node 38 decides:  blue
#
# Node : 39 sees red
# Looking at his neighbours sees { red: 1, blue: 13 }
# it has been influenced towards:  blue
# Node 39 decides:  blue
#
# Node : 40 sees blue
# Looking at his neighbours sees { blue: 11 }
# mantained his decision:  blue
# Node 40 decides:  blue
#
# Node : 41 sees blue
# Looking at his neighbours sees { blue: 12, red: 1 }
# mantained his decision:  blue
# Node 41 decides:  blue
#
# Node : 42 sees blue
# Looking at his neighbours sees { blue: 9, red: 1 }
# mantained his decision:  blue
# Node 42 decides:  blue
#
# Node : 43 sees blue
# Looking at his neighbours sees { blue: 10 }
# mantained his decision:  blue
# Node 43 decides:  blue
#
# Node : 44 sees red
# Looking at his neighbours sees { blue: 9 }
# it has been influenced towards:  blue
# Node 44 decides:  blue
#
# Node : 45 sees blue
# Looking at his neighbours sees { blue: 13 }
# mantained his decision:  blue
# Node 45 decides:  blue
#
# Node : 46 sees blue
# Looking at his neighbours sees { blue: 20, red: 1 }
# mantained his decision:  blue
# Node 46 decides:  blue
#
# Node : 47 sees blue
# Looking at his neighbours sees { blue: 15 }
# mantained his decision:  blue
# Node 47 decides:  blue
#
# Node : 48 sees blue
# Looking at his neighbours sees { blue: 14, red: 1 }
# mantained his decision:  blue
# Node 48 decides:  blue
#
# Node : 49 sees blue
# Looking at his neighbours sees { red: 1, blue: 12 }
# mantained his decision:  blue
# Node 49 decides:  blue
#
# ********* Statistics Summary *********
#
#
# Influencing indexes for node 0 :  []
# Influencing indexes for node 1 :  []
# Influencing indexes for node 2 :  []
# Influencing indexes for node 3 :  []
# Influencing indexes for node 4 :  [ 3 ]
# Influencing indexes for node 5 :  [ 2 ]
# Influencing indexes for node 6 :  [ 0, 1, 2, 5 ]
# Influencing indexes for node 7 :  [ 4 ]
# Influencing indexes for node 8 :  [ 1, 2, 5 ]
# Influencing indexes for node 9 :  [ 0, 4, 8 ]
# Influencing indexes for node 10 :  [ 5 ]
# Influencing indexes for node 11 :  [ 3, 5 ]
# Influencing indexes for node 12 :  [ 0, 1, 3, 4, 5 ]
# Influencing indexes for node 13 :  [ 0, 1, 4, 5, 12 ]
# Influencing indexes for node 14 :  [ 0, 1, 2, 3, 6 ]
# Influencing indexes for node 15 :  [ 4, 5, 6, 8, 10, 12, 13 ]
# Influencing indexes for node 16 :  [ 2, 3, 8, 9, 13 ]
# Influencing indexes for node 17 :  [ 0, 1, 2, 8, 13, 14, 15 ]
# Influencing indexes for node 18 :  [ 0, 7, 8, 9, 10, 17 ]
# Influencing indexes for node 19 :  [ 7, 12, 13, 15, 16, 18 ]
# Influencing indexes for node 20 :  [ 0, 4, 12, 17 ]
# Influencing indexes for node 21 :  [ 7, 9 ]
# Influencing indexes for node 22 :  [ 3, 4, 6, 7, 8, 11, 12, 14, 15 ]
# Influencing indexes for node 23 :  [ 1, 3, 9, 12, 13, 20 ]
# Influencing indexes for node 24 :  [ 3, 5, 7, 10, 14, 16, 17, 18, 21 ]
# Influencing indexes for node 25 :  [ 2, 4, 5, 6, 10, 11, 13, 18, 19, 21, 22, 24 ]
# Influencing indexes for node 26 :  [ 2, 3, 5, 6, 10, 13, 14, 22 ]
# Influencing indexes for node 27 :  [ 0, 1, 3, 5, 7, 8, 14, 17, 18, 19, 26 ]
# Influencing indexes for node 28 :  [ 1, 2, 5, 6, 9, 10, 12, 13, 23, 24, 25, 26 ]
# Influencing indexes for node 29 :  [ 1, 2, 8, 10, 12, 18, 21, 22 ]
# Influencing indexes for node 30 :  [ 3, 5, 19, 22, 23, 25, 27 ]
# Influencing indexes for node 31 :  [ 2, 8, 12, 14, 23, 25, 26 ]
# Influencing indexes for node 32 :  [ 2, 9, 10, 11, 13, 16, 23, 25, 30 ]
# Influencing indexes for node 33 :  [ 0, 4, 7, 8, 9, 11, 14, 16, 20, 21, 25, 26, 28, 31, 32 ]
# Influencing indexes for node 34 :  [ 1, 3, 10, 26, 27 ]
# Influencing indexes for node 35 :  [ 0, 5, 6, 9, 14, 15, 18, 20, 23, 24, 26, 28, 29 ]
# Influencing indexes for node 36 :  [ 0, 2, 3, 10, 11, 22, 23, 24, 25, 26, 33, 34, 35 ]
# Influencing indexes for node 37 :  [ 1, 4, 6, 8, 11, 12, 14, 27, 28, 32, 33, 36 ]
# Influencing indexes for node 38 :  [ 5, 7, 10, 16, 22, 29, 33, 36 ]
# Influencing indexes for node 39 :  [ 1, 3, 6, 7, 14, 15, 23, 25, 27, 28, 31, 32, 35, 36 ]
# Influencing indexes for node 40 :  [ 0, 2, 7, 11, 14, 15, 16, 19, 24, 35, 37 ]
# Influencing indexes for node 41 :  [ 0, 5, 8, 10, 11, 18, 22, 23, 28, 29, 31, 36, 40 ]
# Influencing indexes for node 42 :  [ 2, 3, 8, 10, 11, 19, 24, 26, 29, 38 ]
# Influencing indexes for node 43 :  [ 6, 7, 14, 16, 20, 22, 28, 29, 30, 36 ]
# Influencing indexes for node 44 :  [ 3, 5, 11, 14, 25, 26, 29, 37, 43 ]
# Influencing indexes for node 45 :  [ 0, 2, 3, 10, 18, 24, 25, 28, 29, 32, 33, 42, 43 ]
# Influencing indexes for node 46 :  [ 0, 3, 5, 7, 8, 12, 14, 15, 18, 21, 22, 23, 26, 29, 30, 31, 32, 33, 35, 41, 42 ]
# Influencing indexes for node 47 :  [ 6, 10, 14, 19, 20, 21, 24, 25, 31, 34, 41, 42, 44, 45, 46 ]
# Influencing indexes for node 48 :  [ 0, 1, 13, 21, 22, 23, 27, 29, 30, 31, 33, 38, 39, 43, 44 ]
# Influencing indexes for node 49 :  [ 8, 19, 24, 26, 27, 30, 31, 34, 36, 38, 39, 40, 47 ]
#
# Number of nodes whose opinion didnt matter:  42
# Number of nodes who changed opinion towards the crowd:  12
# BLUE URN
# ./results.csv
# Node : 0 sees red
# Looking at his neighbours sees {}
# mantained his decision:  red
# Node 0 decides:  red
#
# Node : 1 sees blue
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  blue
# Node 1 decides:  blue
#
# Node : 2 sees red
# Looking at his neighbours sees {}
# mantained his decision:  red
# Node 2 decides:  red
#
# Node : 3 sees blue
# Looking at his neighbours sees {}
# mantained his decision:  blue
# Node 3 decides:  blue
#
# Node : 4 sees red
# Looking at his neighbours sees { red: 2 }
# mantained his decision:  red
# Node 4 decides:  red
#
# Node : 5 sees red
# Looking at his neighbours sees { red: 1, blue: 1 }
# mantained his decision:  red
# Node 5 decides:  red
#
# Node : 6 sees blue
# Looking at his neighbours sees { red: 2, blue: 2 }
# mantained his decision:  blue
# Node 6 decides:  blue
#
# Node : 7 sees blue
# Looking at his neighbours sees { red: 1, blue: 1 }
# mantained his decision:  blue
# Node 7 decides:  blue
#
# Node : 8 sees red
# Looking at his neighbours sees { red: 3, blue: 1 }
# mantained his decision:  red
# Node 8 decides:  red
#
# Node : 9 sees blue
# Looking at his neighbours sees { red: 1, blue: 1 }
# mantained his decision:  blue
# Node 9 decides:  blue
#
# Node : 10 sees blue
# Looking at his neighbours sees { red: 1, blue: 2 }
# mantained his decision:  blue
# Node 10 decides:  blue
#
# Node : 11 sees red
# Looking at his neighbours sees { red: 2, blue: 2 }
# mantained his decision:  red
# Node 11 decides:  red
#
# Node : 12 sees red
# Looking at his neighbours sees { blue: 2, red: 4 }
# mantained his decision:  red
# Node 12 decides:  red
#
# Node : 13 sees blue
# Looking at his neighbours sees { blue: 2, red: 4 }
# it has been influenced towards:  red
# Node 13 decides:  red
#
# Node : 14 sees red
# Looking at his neighbours sees { red: 3 }
# mantained his decision:  red
# Node 14 decides:  red
#
# Node : 15 sees blue
# Looking at his neighbours sees { red: 4, blue: 1 }
# it has been influenced towards:  red
# Node 15 decides:  red
#
# Node : 16 sees red
# Looking at his neighbours sees { blue: 2, red: 3 }
# mantained his decision:  red
# Node 16 decides:  red
#
# Node : 17 sees red
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  red
# Node 17 decides:  red
#
# Node : 18 sees red
# Looking at his neighbours sees { blue: 1, red: 6 }
# mantained his decision:  red
# Node 18 decides:  red
#
# Node : 19 sees blue
# Looking at his neighbours sees { red: 5, blue: 1 }
# it has been influenced towards:  red
# Node 19 decides:  red
#
# Node : 20 sees red
# Looking at his neighbours sees { red: 6, blue: 1 }
# mantained his decision:  red
# Node 20 decides:  red
#
# Node : 21 sees blue
# Looking at his neighbours sees { blue: 2, red: 4 }
# it has been influenced towards:  red
# Node 21 decides:  red
#
# Node : 22 sees red
# Looking at his neighbours sees { red: 4 }
# mantained his decision:  red
# Node 22 decides:  red
#
# Node : 23 sees blue
# Looking at his neighbours sees { blue: 3, red: 2 }
# mantained his decision:  blue
# Node 23 decides:  blue
#
# Node : 24 sees blue
# Looking at his neighbours sees { red: 4, blue: 3 }
# mantained his decision:  blue
# Node 24 decides:  blue
#
# Node : 25 sees red
# Looking at his neighbours sees { red: 6, blue: 6 }
# mantained his decision:  red
# Node 25 decides:  red
#
# Node : 26 sees blue
# Looking at his neighbours sees { red: 6, blue: 1 }
# it has been influenced towards:  red
# Node 26 decides:  red
#
# Node : 27 sees red
# Looking at his neighbours sees { blue: 2, red: 6 }
# mantained his decision:  red
# Node 27 decides:  red
#
# Node : 28 sees red
# Looking at his neighbours sees { blue: 1, red: 6 }
# mantained his decision:  red
# Node 28 decides:  red
#
# Node : 29 sees red
# Looking at his neighbours sees { blue: 3, red: 6 }
# mantained his decision:  red
# Node 29 decides:  red
#
# Node : 30 sees blue
# Looking at his neighbours sees { red: 9, blue: 1 }
# it has been influenced towards:  red
# Node 30 decides:  red
#
# Node : 31 sees blue
# Looking at his neighbours sees { red: 3, blue: 3 }
# mantained his decision:  blue
# Node 31 decides:  blue
#
# Node : 32 sees red
# Looking at his neighbours sees { red: 9 }
# mantained his decision:  red
# Node 32 decides:  red
#
# Node : 33 sees red
# Looking at his neighbours sees { red: 8, blue: 4 }
# mantained his decision:  red
# Node 33 decides:  red
#
# Node : 34 sees red
# Looking at his neighbours sees { red: 6, blue: 3 }
# mantained his decision:  red
# Node 34 decides:  red
#
# Node : 35 sees blue
# Looking at his neighbours sees { blue: 4, red: 5 }
# mantained his decision:  blue
# Node 35 decides:  blue
#
# Node : 36 sees blue
# Looking at his neighbours sees { red: 9, blue: 2 }
# it has been influenced towards:  red
# Node 36 decides:  red
#
# Node : 37 sees red
# Looking at his neighbours sees { red: 11, blue: 4 }
# mantained his decision:  red
# Node 37 decides:  red
#
# Node : 38 sees blue
# Looking at his neighbours sees { blue: 4, red: 7 }
# it has been influenced towards:  red
# Node 38 decides:  red
#
# Node : 39 sees red
# Looking at his neighbours sees { red: 9, blue: 3 }
# mantained his decision:  red
# Node 39 decides:  red
#
# Node : 40 sees blue
# Looking at his neighbours sees { blue: 1, red: 4 }
# it has been influenced towards:  red
# Node 40 decides:  red
#
# Node : 41 sees red
# Looking at his neighbours sees { red: 12, blue: 2 }
# mantained his decision:  red
# Node 41 decides:  red
#
# Node : 42 sees red
# Looking at his neighbours sees { blue: 4, red: 11 }
# mantained his decision:  red
# Node 42 decides:  red
#
# Node : 43 sees blue
# Looking at his neighbours sees { red: 8, blue: 2 }
# it has been influenced towards:  red
# Node 43 decides:  red
#
# Node : 44 sees blue
# Looking at his neighbours sees { red: 10, blue: 1 }
# it has been influenced towards:  red
# Node 44 decides:  red
#
# Node : 45 sees blue
# Looking at his neighbours sees { red: 14, blue: 5 }
# it has been influenced towards:  red
# Node 45 decides:  red
#
# Node : 46 sees blue
# Looking at his neighbours sees { red: 13, blue: 5 }
# it has been influenced towards:  red
# Node 46 decides:  red
#
# Node : 47 sees blue
# Looking at his neighbours sees { red: 9, blue: 1 }
# it has been influenced towards:  red
# Node 47 decides:  red
#
# Node : 48 sees blue
# Looking at his neighbours sees { red: 7, blue: 1 }
# it has been influenced towards:  red
# Node 48 decides:  red
#
# Node : 49 sees blue
# Looking at his neighbours sees { blue: 2, red: 14 }
# it has been influenced towards:  red
# Node 49 decides:  red
#
# ********* Statistics Summary *********
#
#
# Influencing indexes for node 0 :  []
# Influencing indexes for node 1 :  [ 0 ]
# Influencing indexes for node 2 :  []
# Influencing indexes for node 3 :  []
# Influencing indexes for node 4 :  [ 0, 2 ]
# Influencing indexes for node 5 :  [ 0, 3 ]
# Influencing indexes for node 6 :  [ 0, 1, 3, 4 ]
# Influencing indexes for node 7 :  [ 2, 6 ]
# Influencing indexes for node 8 :  [ 0, 2, 5, 6 ]
# Influencing indexes for node 9 :  [ 2, 3 ]
# Influencing indexes for node 10 :  [ 2, 3, 6 ]
# Influencing indexes for node 11 :  [ 0, 3, 4, 10 ]
# Influencing indexes for node 12 :  [ 1, 4, 5, 8, 10, 11 ]
# Influencing indexes for node 13 :  [ 1, 2, 3, 5, 8, 11 ]
# Influencing indexes for node 14 :  [ 2, 4, 13 ]
# Influencing indexes for node 15 :  [ 5, 6, 8, 11, 12 ]
# Influencing indexes for node 16 :  [ 1, 2, 6, 11, 13 ]
# Influencing indexes for node 17 :  [ 0 ]
# Influencing indexes for node 18 :  [ 6, 8, 12, 13, 14, 15, 16 ]
# Influencing indexes for node 19 :  [ 0, 2, 7, 8, 15, 16 ]
# Influencing indexes for node 20 :  [ 2, 4, 5, 7, 11, 14, 16 ]
# Influencing indexes for node 21 :  [ 1, 4, 9, 11, 12, 14 ]
# Influencing indexes for node 22 :  [ 4, 13, 15, 19 ]
# Influencing indexes for node 23 :  [ 1, 3, 9, 15, 22 ]
# Influencing indexes for node 24 :  [ 0, 4, 6, 10, 17, 20, 23 ]
# Influencing indexes for node 25 :  [ 0, 1, 2, 3, 6, 7, 8, 9, 13, 15, 16, 24 ]
# Influencing indexes for node 26 :  [ 0, 7, 8, 13, 15, 16, 18 ]
# Influencing indexes for node 27 :  [ 1, 9, 11, 13, 14, 15, 19, 20 ]
# Influencing indexes for node 28 :  [ 3, 5, 13, 16, 20, 25, 26 ]
# Influencing indexes for node 29 :  [ 1, 2, 6, 7, 13, 15, 20, 22, 27 ]
# Influencing indexes for node 30 :  [ 5, 8, 14, 17, 18, 19, 20, 24, 26, 28 ]
# Influencing indexes for node 31 :  [ 2, 3, 9, 18, 23, 27 ]
# Influencing indexes for node 32 :  [ 2, 5, 8, 13, 16, 17, 20, 26, 29 ]
# Influencing indexes for node 33 :  [ 0, 3, 4, 6, 11, 12, 13, 17, 19, 24, 26, 31 ]
# Influencing indexes for node 34 :  [ 0, 6, 12, 15, 23, 30, 31, 32, 33 ]
# Influencing indexes for node 35 :  [ 3, 6, 10, 11, 22, 24, 26, 29, 32 ]
# Influencing indexes for node 36 :  [ 0, 5, 8, 9, 13, 15, 19, 23, 25, 26, 28 ]
# Influencing indexes for node 37 :  [ 0, 1, 2, 4, 5, 8, 10, 11, 12, 16, 23, 26, 30, 34, 35 ]
# Influencing indexes for node 38 :  [ 10, 13, 16, 20, 21, 23, 24, 29, 33, 35, 36 ]
# Influencing indexes for node 39 :  [ 5, 9, 11, 13, 15, 18, 21, 24, 25, 27, 31, 38 ]
# Influencing indexes for node 40 :  [ 1, 30, 36, 37, 38 ]
# Influencing indexes for node 41 :  [ 0, 4, 8, 11, 16, 19, 20, 22, 23, 24, 26, 28, 30, 33 ]
# Influencing indexes for node 42 :  [ 1, 2, 3, 8, 9, 12, 13, 16, 17, 24, 28, 30, 32, 37, 40 ]
# Influencing indexes for node 43 :  [ 2, 8, 15, 16, 26, 27, 31, 32, 34, 35 ]
# Influencing indexes for node 44 :  [ 5, 9, 13, 18, 19, 22, 33, 34, 36, 40, 42 ]
# Influencing indexes for node 45 :  [ 2, 4, 6, 7, 8, 9, 10, 12, 13, 20, 24, 28, 29, 32, 33, 39, 40, 41, 42 ]
# Influencing indexes for node 46 :  [ 0, 1, 2, 3, 4, 6, 12, 13, 14, 16, 18, 20, 28, 31, 32, 35, 36, 38 ]
# Influencing indexes for node 47 :  [ 2, 5, 8, 10, 15, 17, 32, 38, 44, 45 ]
# Influencing indexes for node 48 :  [ 4, 11, 23, 26, 28, 30, 33, 39 ]
# Influencing indexes for node 49 :  [ 3, 14, 20, 21, 23, 25, 26, 28, 29, 30, 33, 39, 40, 42, 43, 47 ]
#
# Number of nodes whose opinion didnt matter:  42
# Number of nodes who changed opinion towards the crowd:  16
# RED URN
# ./results.csv
# Node : 0 sees red
# Looking at his neighbours sees {}
# mantained his decision:  red
# Node 0 decides:  red
#
# Node : 1 sees red
# Looking at his neighbours sees {}
# mantained his decision:  red
# Node 1 decides:  red
#
# Node : 2 sees red
# Looking at his neighbours sees {}
# mantained his decision:  red
# Node 2 decides:  red
#
# Node : 3 sees blue
# Looking at his neighbours sees {}
# mantained his decision:  blue
# Node 3 decides:  blue
#
# Node : 4 sees blue
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  blue
# Node 4 decides:  blue
#
# Node : 5 sees red
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  red
# Node 5 decides:  red
#
# Node : 6 sees blue
# Looking at his neighbours sees { red: 2 }
# it has been influenced towards:  red
# Node 6 decides:  red
#
# Node : 7 sees red
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  red
# Node 7 decides:  red
#
# Node : 8 sees red
# Looking at his neighbours sees { red: 4 }
# mantained his decision:  red
# Node 8 decides:  red
#
# Node : 9 sees red
# Looking at his neighbours sees { red: 3, blue: 1 }
# mantained his decision:  red
# Node 9 decides:  red
#
# Node : 10 sees red
# Looking at his neighbours sees { red: 2 }
# mantained his decision:  red
# Node 10 decides:  red
#
# Node : 11 sees red
# Looking at his neighbours sees { red: 4, blue: 1 }
# mantained his decision:  red
# Node 11 decides:  red
#
# Node : 12 sees red
# Looking at his neighbours sees { red: 2 }
# mantained his decision:  red
# Node 12 decides:  red
#
# Node : 13 sees red
# Looking at his neighbours sees { red: 6 }
# mantained his decision:  red
# Node 13 decides:  red
#
# Node : 14 sees red
# Looking at his neighbours sees { red: 5 }
# mantained his decision:  red
# Node 14 decides:  red
#
# Node : 15 sees red
# Looking at his neighbours sees { red: 4, blue: 1 }
# mantained his decision:  red
# Node 15 decides:  red
#
# Node : 16 sees blue
# Looking at his neighbours sees { red: 6 }
# it has been influenced towards:  red
# Node 16 decides:  red
#
# Node : 17 sees red
# Looking at his neighbours sees { red: 8, blue: 2 }
# mantained his decision:  red
# Node 17 decides:  red
#
# Node : 18 sees red
# Looking at his neighbours sees { red: 8, blue: 1 }
# mantained his decision:  red
# Node 18 decides:  red
#
# Node : 19 sees blue
# Looking at his neighbours sees { red: 7 }
# it has been influenced towards:  red
# Node 19 decides:  red
#
# Node : 20 sees red
# Looking at his neighbours sees { red: 5, blue: 2 }
# mantained his decision:  red
# Node 20 decides:  red
#
# Node : 21 sees blue
# Looking at his neighbours sees { red: 4, blue: 1 }
# it has been influenced towards:  red
# Node 21 decides:  red
#
# Node : 22 sees red
# Looking at his neighbours sees { blue: 1, red: 6 }
# mantained his decision:  red
# Node 22 decides:  red
#
# Node : 23 sees red
# Looking at his neighbours sees { red: 9, blue: 1 }
# mantained his decision:  red
# Node 23 decides:  red
#
# Node : 24 sees red
# Looking at his neighbours sees { blue: 1, red: 5 }
# mantained his decision:  red
# Node 24 decides:  red
#
# Node : 25 sees red
# Looking at his neighbours sees { blue: 1, red: 3 }
# mantained his decision:  red
# Node 25 decides:  red
#
# Node : 26 sees red
# Looking at his neighbours sees { red: 9 }
# mantained his decision:  red
# Node 26 decides:  red
#
# Node : 27 sees blue
# Looking at his neighbours sees { red: 3 }
# it has been influenced towards:  red
# Node 27 decides:  red
#
# Node : 28 sees red
# Looking at his neighbours sees { red: 7 }
# mantained his decision:  red
# Node 28 decides:  red
#
# Node : 29 sees blue
# Looking at his neighbours sees { blue: 1, red: 9 }
# it has been influenced towards:  red
# Node 29 decides:  red
#
# Node : 30 sees red
# Looking at his neighbours sees { red: 5 }
# mantained his decision:  red
# Node 30 decides:  red
#
# Node : 31 sees red
# Looking at his neighbours sees { blue: 1, red: 6 }
# mantained his decision:  red
# Node 31 decides:  red
#
# Node : 32 sees red
# Looking at his neighbours sees { red: 8 }
# mantained his decision:  red
# Node 32 decides:  red
#
# Node : 33 sees red
# Looking at his neighbours sees { red: 10 }
# mantained his decision:  red
# Node 33 decides:  red
#
# Node : 34 sees blue
# Looking at his neighbours sees { red: 9, blue: 1 }
# it has been influenced towards:  red
# Node 34 decides:  red
#
# Node : 35 sees red
# Looking at his neighbours sees { red: 10 }
# mantained his decision:  red
# Node 35 decides:  red
#
# Node : 36 sees red
# Looking at his neighbours sees { red: 12 }
# mantained his decision:  red
# Node 36 decides:  red
#
# Node : 37 sees red
# Looking at his neighbours sees { red: 9 }
# mantained his decision:  red
# Node 37 decides:  red
#
# Node : 38 sees red
# Looking at his neighbours sees { red: 18 }
# mantained his decision:  red
# Node 38 decides:  red
#
# Node : 39 sees red
# Looking at his neighbours sees { red: 15 }
# mantained his decision:  red
# Node 39 decides:  red
#
# Node : 40 sees red
# Looking at his neighbours sees { red: 11 }
# mantained his decision:  red
# Node 40 decides:  red
#
# Node : 41 sees red
# Looking at his neighbours sees { red: 7 }
# mantained his decision:  red
# Node 41 decides:  red
#
# Node : 42 sees red
# Looking at his neighbours sees { red: 19 }
# mantained his decision:  red
# Node 42 decides:  red
#
# Node : 43 sees red
# Looking at his neighbours sees { blue: 2, red: 12 }
# mantained his decision:  red
# Node 43 decides:  red
#
# Node : 44 sees blue
# Looking at his neighbours sees { red: 11, blue: 2 }
# it has been influenced towards:  red
# Node 44 decides:  red
#
# Node : 45 sees red
# Looking at his neighbours sees { red: 17 }
# mantained his decision:  red
# Node 45 decides:  red
#
# Node : 46 sees red
# Looking at his neighbours sees { red: 18 }
# mantained his decision:  red
# Node 46 decides:  red
#
# Node : 47 sees red
# Looking at his neighbours sees { blue: 2, red: 14 }
# mantained his decision:  red
# Node 47 decides:  red
#
# Node : 48 sees red
# Looking at his neighbours sees { blue: 2, red: 11 }
# mantained his decision:  red
# Node 48 decides:  red
#
# Node : 49 sees red
# Looking at his neighbours sees { red: 15 }
# mantained his decision:  red
# Node 49 decides:  red
#
# ********* Statistics Summary *********
#
#
# Influencing indexes for node 0 :  []
# Influencing indexes for node 1 :  []
# Influencing indexes for node 2 :  []
# Influencing indexes for node 3 :  []
# Influencing indexes for node 4 :  [ 0 ]
# Influencing indexes for node 5 :  [ 0 ]
# Influencing indexes for node 6 :  [ 2, 5 ]
# Influencing indexes for node 7 :  [ 1 ]
# Influencing indexes for node 8 :  [ 0, 1, 2, 7 ]
# Influencing indexes for node 9 :  [ 1, 3, 5, 8 ]
# Influencing indexes for node 10 :  [ 0, 8 ]
# Influencing indexes for node 11 :  [ 0, 3, 7, 8, 9 ]
# Influencing indexes for node 12 :  [ 5, 6 ]
# Influencing indexes for node 13 :  [ 1, 5, 8, 10, 11, 12 ]
# Influencing indexes for node 14 :  [ 0, 1, 2, 5, 12 ]
# Influencing indexes for node 15 :  [ 2, 4, 5, 8, 12 ]
# Influencing indexes for node 16 :  [ 0, 1, 6, 8, 10, 12 ]
# Influencing indexes for node 17 :  [ 0, 2, 3, 4, 6, 7, 8, 9, 10, 14 ]
# Influencing indexes for node 18 :  [ 1, 2, 3, 5, 9, 10, 13, 15, 16 ]
# Influencing indexes for node 19 :  [ 0, 1, 7, 8, 9, 14, 17 ]
# Influencing indexes for node 20 :  [ 1, 3, 4, 5, 6, 16, 17 ]
# Influencing indexes for node 21 :  [ 0, 2, 3, 5, 11 ]
# Influencing indexes for node 22 :  [ 3, 6, 8, 9, 11, 12, 17 ]
# Influencing indexes for node 23 :  [ 0, 2, 4, 6, 7, 8, 11, 12, 14, 21 ]
# Influencing indexes for node 24 :  [ 4, 7, 12, 16, 21, 23 ]
# Influencing indexes for node 25 :  [ 4, 11, 16, 19 ]
# Influencing indexes for node 26 :  [ 6, 7, 8, 12, 13, 15, 22, 23, 25 ]
# Influencing indexes for node 27 :  [ 8, 18, 19 ]
# Influencing indexes for node 28 :  [ 0, 15, 17, 18, 20, 21, 26 ]
# Influencing indexes for node 29 :  [ 3, 5, 6, 11, 14, 18, 20, 25, 27, 28 ]
# Influencing indexes for node 30 :  [ 7, 9, 10, 14, 23 ]
# Influencing indexes for node 31 :  [ 4, 7, 13, 14, 25, 28, 30 ]
# Influencing indexes for node 32 :  [ 0, 6, 12, 14, 22, 24, 25, 28 ]
# Influencing indexes for node 33 :  [ 1, 5, 6, 10, 12, 13, 15, 20, 28, 31 ]
# Influencing indexes for node 34 :  [ 1, 4, 5, 9, 17, 24, 25, 26, 28, 29 ]
# Influencing indexes for node 35 :  [ 10, 14, 17, 19, 20, 23, 24, 27, 31, 34 ]
# Influencing indexes for node 36 :  [ 1, 5, 7, 9, 15, 17, 22, 23, 29, 31, 32, 34 ]
# Influencing indexes for node 37 :  [ 6, 8, 21, 27, 28, 30, 31, 33, 36 ]
# Influencing indexes for node 38 :  [ 2, 7, 9, 12, 13, 15, 19, 20, 22, 23, 25, 26, 28, 29, 32, 33, 34, 36 ]
# Influencing indexes for node 39 :  [ 2, 10, 14, 17, 20, 21, 24, 25, 28, 30, 31, 32, 33, 36, 38 ]
# Influencing indexes for node 40 :  [ 1, 10, 12, 14, 15, 16, 19, 21, 22, 34, 38 ]
# Influencing indexes for node 41 :  [ 6, 10, 15, 19, 27, 35, 40 ]
# Influencing indexes for node 42 :  [ 0, 1, 2, 5, 6, 8, 9, 12, 16, 18, 20, 23, 25, 26, 31, 32, 33, 39, 41 ]
# Influencing indexes for node 43 :  [ 3, 4, 6, 11, 17, 19, 20, 21, 25, 27, 29, 32, 37, 39 ]
# Influencing indexes for node 44 :  [ 2, 3, 4, 8, 13, 16, 21, 22, 24, 27, 37, 39, 43 ]
# Influencing indexes for node 45 :  [ 1, 2, 6, 8, 10, 11, 13, 18, 20, 21, 25, 29, 32, 36, 38, 42, 44 ]
# Influencing indexes for node 46 :  [ 0, 5, 6, 7, 14, 15, 16, 17, 19, 22, 25, 29, 33, 35, 36, 37, 38, 39 ]
# Influencing indexes for node 47 :  [ 3, 4, 8, 10, 11, 14, 16, 17, 24, 29, 32, 39, 41, 44, 45, 46 ]
# Influencing indexes for node 48 :  [ 3, 4, 5, 17, 18, 21, 22, 29, 31, 35, 36, 44, 47 ]
# Influencing indexes for node 49 :  [ 2, 11, 12, 13, 17, 22, 24, 30, 32, 34, 40, 42, 45, 47, 48 ]
#
# Number of nodes whose opinion didnt matter:  43
# Number of nodes who changed opinion towards the crowd:  8
# RED URN
# ./results.csv
# Node : 0 sees red
# Looking at his neighbours sees {}
# mantained his decision:  red
# Node 0 decides:  red
#
# Node : 1 sees blue
# Looking at his neighbours sees {}
# mantained his decision:  blue
# Node 1 decides:  blue
#
# Node : 2 sees red
# Looking at his neighbours sees {}
# mantained his decision:  red
# Node 2 decides:  red
#
# Node : 3 sees red
# Looking at his neighbours sees { red: 1, blue: 1 }
# mantained his decision:  red
# Node 3 decides:  red
#
# Node : 4 sees red
# Looking at his neighbours sees { blue: 1 }
# mantained his decision:  red
# Node 4 decides:  red
#
# Node : 5 sees blue
# Looking at his neighbours sees { red: 2 }
# it has been influenced towards:  red
# Node 5 decides:  red
#
# Node : 6 sees blue
# Looking at his neighbours sees { blue: 1, red: 1 }
# mantained his decision:  blue
# Node 6 decides:  blue
#
# Node : 7 sees blue
# Looking at his neighbours sees { blue: 1, red: 1 }
# mantained his decision:  blue
# Node 7 decides:  blue
#
# Node : 8 sees red
# Looking at his neighbours sees { red: 1, blue: 2 }
# mantained his decision:  red
# Node 8 decides:  red
#
# Node : 9 sees red
# Looking at his neighbours sees { blue: 1, red: 1 }
# mantained his decision:  red
# Node 9 decides:  red
#
# Node : 10 sees red
# Looking at his neighbours sees { red: 3, blue: 2 }
# mantained his decision:  red
# Node 10 decides:  red
#
# Node : 11 sees red
# Looking at his neighbours sees { blue: 2, red: 2 }
# mantained his decision:  red
# Node 11 decides:  red
#
# Node : 12 sees red
# Looking at his neighbours sees { red: 3, blue: 1 }
# mantained his decision:  red
# Node 12 decides:  red
#
# Node : 13 sees red
# Looking at his neighbours sees { red: 4 }
# mantained his decision:  red
# Node 13 decides:  red
#
# Node : 14 sees blue
# Looking at his neighbours sees { red: 2 }
# it has been influenced towards:  red
# Node 14 decides:  red
#
# Node : 15 sees red
# Looking at his neighbours sees { red: 4, blue: 1 }
# mantained his decision:  red
# Node 15 decides:  red
#
# Node : 16 sees red
# Looking at his neighbours sees { blue: 2, red: 6 }
# mantained his decision:  red
# Node 16 decides:  red
#
# Node : 17 sees blue
# Looking at his neighbours sees { blue: 1, red: 4 }
# it has been influenced towards:  red
# Node 17 decides:  red
#
# Node : 18 sees red
# Looking at his neighbours sees { blue: 2, red: 3 }
# mantained his decision:  red
# Node 18 decides:  red
#
# Node : 19 sees blue
# Looking at his neighbours sees { blue: 1, red: 2 }
# mantained his decision:  blue
# Node 19 decides:  blue
#
# Node : 20 sees blue
# Looking at his neighbours sees { red: 4, blue: 1 }
# it has been influenced towards:  red
# Node 20 decides:  red
#
# Node : 21 sees red
# Looking at his neighbours sees { red: 7, blue: 2 }
# mantained his decision:  red
# Node 21 decides:  red
#
# Node : 22 sees red
# Looking at his neighbours sees { red: 7, blue: 2 }
# mantained his decision:  red
# Node 22 decides:  red
#
# Node : 23 sees blue
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  blue
# Node 23 decides:  blue
#
# Node : 24 sees blue
# Looking at his neighbours sees { red: 7, blue: 1 }
# it has been influenced towards:  red
# Node 24 decides:  red
#
# Node : 25 sees red
# Looking at his neighbours sees { blue: 1, red: 5 }
# mantained his decision:  red
# Node 25 decides:  red
#
# Node : 26 sees red
# Looking at his neighbours sees { red: 12 }
# mantained his decision:  red
# Node 26 decides:  red
#
# Node : 27 sees blue
# Looking at his neighbours sees { red: 9, blue: 1 }
# it has been influenced towards:  red
# Node 27 decides:  red
#
# Node : 28 sees blue
# Looking at his neighbours sees { red: 9 }
# it has been influenced towards:  red
# Node 28 decides:  red
#
# Node : 29 sees red
# Looking at his neighbours sees { red: 7, blue: 3 }
# mantained his decision:  red
# Node 29 decides:  red
#
# Node : 30 sees red
# Looking at his neighbours sees { blue: 2, red: 8 }
# mantained his decision:  red
# Node 30 decides:  red
#
# Node : 31 sees blue
# Looking at his neighbours sees { red: 7 }
# it has been influenced towards:  red
# Node 31 decides:  red
#
# Node : 32 sees red
# Looking at his neighbours sees { red: 8, blue: 1 }
# mantained his decision:  red
# Node 32 decides:  red
#
# Node : 33 sees blue
# Looking at his neighbours sees { blue: 1, red: 9 }
# it has been influenced towards:  red
# Node 33 decides:  red
#
# Node : 34 sees red
# Looking at his neighbours sees { red: 7, blue: 2 }
# mantained his decision:  red
# Node 34 decides:  red
#
# Node : 35 sees red
# Looking at his neighbours sees { red: 14 }
# mantained his decision:  red
# Node 35 decides:  red
#
# Node : 36 sees red
# Looking at his neighbours sees { red: 10, blue: 1 }
# mantained his decision:  red
# Node 36 decides:  red
#
# Node : 37 sees red
# Looking at his neighbours sees { red: 12, blue: 3 }
# mantained his decision:  red
# Node 37 decides:  red
#
# Node : 38 sees red
# Looking at his neighbours sees { red: 16, blue: 3 }
# mantained his decision:  red
# Node 38 decides:  red
#
# Node : 39 sees red
# Looking at his neighbours sees { red: 10, blue: 2 }
# mantained his decision:  red
# Node 39 decides:  red
#
# Node : 40 sees red
# Looking at his neighbours sees { red: 7, blue: 1 }
# mantained his decision:  red
# Node 40 decides:  red
#
# Node : 41 sees red
# Looking at his neighbours sees { red: 10, blue: 2 }
# mantained his decision:  red
# Node 41 decides:  red
#
# Node : 42 sees red
# Looking at his neighbours sees { red: 13 }
# mantained his decision:  red
# Node 42 decides:  red
#
# Node : 43 sees red
# Looking at his neighbours sees { red: 11, blue: 1 }
# mantained his decision:  red
# Node 43 decides:  red
#
# Node : 44 sees red
# Looking at his neighbours sees { red: 12 }
# mantained his decision:  red
# Node 44 decides:  red
#
# Node : 45 sees red
# Looking at his neighbours sees { red: 12, blue: 2 }
# mantained his decision:  red
# Node 45 decides:  red
#
# Node : 46 sees blue
# Looking at his neighbours sees { red: 10, blue: 1 }
# it has been influenced towards:  red
# Node 46 decides:  red
#
# Node : 47 sees red
# Looking at his neighbours sees { red: 10, blue: 2 }
# mantained his decision:  red
# Node 47 decides:  red
#
# Node : 48 sees red
# Looking at his neighbours sees { red: 18, blue: 1 }
# mantained his decision:  red
# Node 48 decides:  red
#
# Node : 49 sees red
# Looking at his neighbours sees { red: 15 }
# mantained his decision:  red
# Node 49 decides:  red
#
# ********* Statistics Summary *********
#
#
# Influencing indexes for node 0 :  []
# Influencing indexes for node 1 :  []
# Influencing indexes for node 2 :  []
# Influencing indexes for node 3 :  [ 0, 1 ]
# Influencing indexes for node 4 :  [ 1 ]
# Influencing indexes for node 5 :  [ 3, 4 ]
# Influencing indexes for node 6 :  [ 1, 5 ]
# Influencing indexes for node 7 :  [ 1, 5 ]
# Influencing indexes for node 8 :  [ 3, 6, 7 ]
# Influencing indexes for node 9 :  [ 6, 8 ]
# Influencing indexes for node 10 :  [ 0, 3, 6, 7, 9 ]
# Influencing indexes for node 11 :  [ 1, 7, 9, 10 ]
# Influencing indexes for node 12 :  [ 0, 2, 6, 10 ]
# Influencing indexes for node 13 :  [ 0, 2, 3, 8 ]
# Influencing indexes for node 14 :  [ 5, 10 ]
# Influencing indexes for node 15 :  [ 3, 4, 7, 9, 13 ]
# Influencing indexes for node 16 :  [ 1, 3, 4, 7, 9, 10, 12, 14 ]
# Influencing indexes for node 17 :  [ 1, 11, 12, 14, 15 ]
# Influencing indexes for node 18 :  [ 1, 3, 6, 8, 13 ]
# Influencing indexes for node 19 :  [ 7, 9, 13 ]
# Influencing indexes for node 20 :  [ 2, 6, 8, 11, 12 ]
# Influencing indexes for node 21 :  [ 0, 1, 2, 7, 10, 12, 13, 14, 18 ]
# Influencing indexes for node 22 :  [ 0, 4, 6, 7, 9, 11, 13, 18, 20 ]
# Influencing indexes for node 23 :  [ 18 ]
# Influencing indexes for node 24 :  [ 0, 5, 6, 8, 9, 11, 12, 16 ]
# Influencing indexes for node 25 :  [ 1, 2, 4, 11, 16, 22 ]
# Influencing indexes for node 26 :  [ 0, 2, 4, 9, 10, 12, 15, 16, 18, 20, 21, 25 ]
# Influencing indexes for node 27 :  [ 2, 5, 8, 12, 13, 15, 19, 21, 22, 25 ]
# Influencing indexes for node 28 :  [ 0, 3, 15, 16, 18, 20, 21, 22, 24 ]
# Influencing indexes for node 29 :  [ 5, 7, 9, 11, 19, 20, 21, 22, 23, 26 ]
# Influencing indexes for node 30 :  [ 6, 11, 13, 20, 21, 22, 23, 24, 25, 28 ]
# Influencing indexes for node 31 :  [ 3, 9, 10, 13, 16, 29, 30 ]
# Influencing indexes for node 32 :  [ 2, 4, 6, 18, 21, 22, 24, 30, 31 ]
# Influencing indexes for node 33 :  [ 6, 8, 12, 14, 16, 18, 26, 27, 28, 30 ]
# Influencing indexes for node 34 :  [ 0, 6, 9, 13, 19, 21, 26, 30, 33 ]
# Influencing indexes for node 35 :  [ 2, 8, 9, 10, 11, 13, 15, 18, 21, 22, 25, 28, 33, 34 ]
# Influencing indexes for node 36 :  [ 3, 8, 9, 12, 18, 19, 24, 26, 32, 33, 35 ]
# Influencing indexes for node 37 :  [ 4, 5, 6, 7, 8, 9, 11, 14, 16, 17, 23, 26, 28, 33, 34 ]
# Influencing indexes for node 38 :  [ 0, 1, 4, 5, 6, 8, 9, 11, 13, 15, 17, 18, 19, 26, 30, 31, 32, 33, 36 ]
# Influencing indexes for node 39 :  [ 3, 7, 8, 14, 15, 19, 21, 22, 25, 30, 35, 38 ]
# Influencing indexes for node 40 :  [ 3, 4, 18, 19, 22, 34, 37, 38 ]
# Influencing indexes for node 41 :  [ 2, 3, 4, 7, 9, 17, 23, 26, 29, 30, 37, 40 ]
# Influencing indexes for node 42 :  [ 3, 4, 9, 10, 11, 14, 18, 24, 26, 27, 32, 33, 40 ]
# Influencing indexes for node 43 :  [ 0, 6, 9, 10, 14, 17, 26, 27, 31, 33, 34, 40 ]
# Influencing indexes for node 44 :  [ 3, 5, 10, 11, 12, 17, 18, 22, 24, 27, 37, 38 ]
# Influencing indexes for node 45 :  [ 0, 6, 7, 9, 10, 18, 20, 28, 30, 31, 34, 39, 40, 41 ]
# Influencing indexes for node 46 :  [ 3, 11, 13, 15, 22, 23, 28, 29, 36, 39, 40 ]
# Influencing indexes for node 47 :  [ 0, 1, 8, 12, 16, 19, 30, 31, 39, 42, 43, 46 ]
# Influencing indexes for node 48 :  [ 0, 6, 8, 10, 12, 14, 15, 17, 20, 21, 24, 25, 30, 31, 34, 39, 41, 42, 44 ]
# Influencing indexes for node 49 :  [ 5, 9, 12, 18, 27, 29, 31, 33, 37, 41, 43, 44, 46, 47, 48 ]
#
# Number of nodes whose opinion didnt matter:  41
# Number of nodes who changed opinion towards the crowd:  10
# BLUE URN
# ./results.csv
# Node : 0 sees red
# Looking at his neighbours sees {}
# mantained his decision:  red
# Node 0 decides:  red
#
# Node : 1 sees blue
# Looking at his neighbours sees {}
# mantained his decision:  blue
# Node 1 decides:  blue
#
# Node : 2 sees red
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  red
# Node 2 decides:  red
#
# Node : 3 sees blue
# Looking at his neighbours sees { blue: 1, red: 1 }
# mantained his decision:  blue
# Node 3 decides:  blue
#
# Node : 4 sees blue
# Looking at his neighbours sees {}
# mantained his decision:  blue
# Node 4 decides:  blue
#
# Node : 5 sees red
# Looking at his neighbours sees { blue: 1, red: 1 }
# mantained his decision:  red
# Node 5 decides:  red
#
# Node : 6 sees blue
# Looking at his neighbours sees { blue: 1, red: 1 }
# mantained his decision:  blue
# Node 6 decides:  blue
#
# Node : 7 sees blue
# Looking at his neighbours sees { red: 2, blue: 2 }
# mantained his decision:  blue
# Node 7 decides:  blue
#
# Node : 8 sees blue
# Looking at his neighbours sees { red: 1, blue: 2 }
# mantained his decision:  blue
# Node 8 decides:  blue
#
# Node : 9 sees blue
# Looking at his neighbours sees { blue: 3 }
# mantained his decision:  blue
# Node 9 decides:  blue
#
# Node : 10 sees red
# Looking at his neighbours sees { red: 1, blue: 2 }
# mantained his decision:  red
# Node 10 decides:  red
#
# Node : 11 sees blue
# Looking at his neighbours sees { blue: 4 }
# mantained his decision:  blue
# Node 11 decides:  blue
#
# Node : 12 sees red
# Looking at his neighbours sees { blue: 1, red: 1 }
# mantained his decision:  red
# Node 12 decides:  red
#
# Node : 13 sees blue
# Looking at his neighbours sees { blue: 2, red: 2 }
# mantained his decision:  blue
# Node 13 decides:  blue
#
# Node : 14 sees blue
# Looking at his neighbours sees { blue: 1 }
# mantained his decision:  blue
# Node 14 decides:  blue
#
# Node : 15 sees blue
# Looking at his neighbours sees { red: 3, blue: 1 }
# it has been influenced towards:  red
# Node 15 decides:  red
#
# Node : 16 sees blue
# Looking at his neighbours sees { red: 1, blue: 3 }
# mantained his decision:  blue
# Node 16 decides:  blue
#
# Node : 17 sees red
# Looking at his neighbours sees { red: 2 }
# mantained his decision:  red
# Node 17 decides:  red
#
# Node : 18 sees blue
# Looking at his neighbours sees { red: 4, blue: 5 }
# mantained his decision:  blue
# Node 18 decides:  blue
#
# Node : 19 sees blue
# Looking at his neighbours sees { blue: 2 }
# mantained his decision:  blue
# Node 19 decides:  blue
#
# Node : 20 sees blue
# Looking at his neighbours sees { blue: 3, red: 2 }
# mantained his decision:  blue
# Node 20 decides:  blue
#
# Node : 21 sees blue
# Looking at his neighbours sees { blue: 4, red: 3 }
# mantained his decision:  blue
# Node 21 decides:  blue
#
# Node : 22 sees red
# Looking at his neighbours sees { blue: 3, red: 1 }
# it has been influenced towards:  blue
# Node 22 decides:  blue
#
# Node : 23 sees blue
# Looking at his neighbours sees { red: 3, blue: 6 }
# mantained his decision:  blue
# Node 23 decides:  blue
#
# Node : 24 sees blue
# Looking at his neighbours sees { blue: 2, red: 1 }
# mantained his decision:  blue
# Node 24 decides:  blue
#
# Node : 25 sees red
# Looking at his neighbours sees { red: 2, blue: 7 }
# it has been influenced towards:  blue
# Node 25 decides:  blue
#
# Node : 26 sees red
# Looking at his neighbours sees { red: 3, blue: 5 }
# it has been influenced towards:  blue
# Node 26 decides:  blue
#
# Node : 27 sees blue
# Looking at his neighbours sees { blue: 5, red: 5 }
# mantained his decision:  blue
# Node 27 decides:  blue
#
# Node : 28 sees blue
# Looking at his neighbours sees { blue: 7, red: 2 }
# mantained his decision:  blue
# Node 28 decides:  blue
#
# Node : 29 sees blue
# Looking at his neighbours sees { blue: 5, red: 1 }
# mantained his decision:  blue
# Node 29 decides:  blue
#
# Node : 30 sees red
# Looking at his neighbours sees { blue: 6 }
# it has been influenced towards:  blue
# Node 30 decides:  blue
#
# Node : 31 sees blue
# Looking at his neighbours sees { blue: 8, red: 1 }
# mantained his decision:  blue
# Node 31 decides:  blue
#
# Node : 32 sees blue
# Looking at his neighbours sees { blue: 8, red: 3 }
# mantained his decision:  blue
# Node 32 decides:  blue
#
# Node : 33 sees blue
# Looking at his neighbours sees { blue: 9, red: 3 }
# mantained his decision:  blue
# Node 33 decides:  blue
#
# Node : 34 sees red
# Looking at his neighbours sees { red: 4, blue: 15 }
# it has been influenced towards:  blue
# Node 34 decides:  blue
#
# Node : 35 sees blue
# Looking at his neighbours sees { red: 3, blue: 12 }
# mantained his decision:  blue
# Node 35 decides:  blue
#
# Node : 36 sees blue
# Looking at his neighbours sees { red: 4, blue: 10 }
# mantained his decision:  blue
# Node 36 decides:  blue
#
# Node : 37 sees blue
# Looking at his neighbours sees { blue: 8 }
# mantained his decision:  blue
# Node 37 decides:  blue
#
# Node : 38 sees red
# Looking at his neighbours sees { red: 2, blue: 10 }
# it has been influenced towards:  blue
# Node 38 decides:  blue
#
# Node : 39 sees red
# Looking at his neighbours sees { red: 3, blue: 6 }
# it has been influenced towards:  blue
# Node 39 decides:  blue
#
# Node : 40 sees blue
# Looking at his neighbours sees { blue: 9, red: 2 }
# mantained his decision:  blue
# Node 40 decides:  blue
#
# Node : 41 sees blue
# Looking at his neighbours sees { red: 5, blue: 9 }
# mantained his decision:  blue
# Node 41 decides:  blue
#
# Node : 42 sees red
# Looking at his neighbours sees { red: 2, blue: 13 }
# it has been influenced towards:  blue
# Node 42 decides:  blue
#
# Node : 43 sees red
# Looking at his neighbours sees { red: 1, blue: 13 }
# it has been influenced towards:  blue
# Node 43 decides:  blue
#
# Node : 44 sees blue
# Looking at his neighbours sees { blue: 8 }
# mantained his decision:  blue
# Node 44 decides:  blue
#
# Node : 45 sees blue
# Looking at his neighbours sees { blue: 9, red: 1 }
# mantained his decision:  blue
# Node 45 decides:  blue
#
# Node : 46 sees blue
# Looking at his neighbours sees { blue: 9, red: 2 }
# mantained his decision:  blue
# Node 46 decides:  blue
#
# Node : 47 sees blue
# Looking at his neighbours sees { red: 2, blue: 21 }
# mantained his decision:  blue
# Node 47 decides:  blue
#
# Node : 48 sees blue
# Looking at his neighbours sees { blue: 13 }
# mantained his decision:  blue
# Node 48 decides:  blue
#
# Node : 49 sees blue
# Looking at his neighbours sees { blue: 14, red: 2 }
# mantained his decision:  blue
# Node 49 decides:  blue
#
# ********* Statistics Summary *********
#
#
# Influencing indexes for node 0 :  []
# Influencing indexes for node 1 :  []
# Influencing indexes for node 2 :  [ 0 ]
# Influencing indexes for node 3 :  [ 1, 2 ]
# Influencing indexes for node 4 :  []
# Influencing indexes for node 5 :  [ 1, 2 ]
# Influencing indexes for node 6 :  [ 1, 5 ]
# Influencing indexes for node 7 :  [ 0, 1, 5, 6 ]
# Influencing indexes for node 8 :  [ 0, 1, 7 ]
# Influencing indexes for node 9 :  [ 1, 4, 6 ]
# Influencing indexes for node 10 :  [ 0, 3, 6 ]
# Influencing indexes for node 11 :  [ 1, 6, 7, 9 ]
# Influencing indexes for node 12 :  [ 3, 10 ]
# Influencing indexes for node 13 :  [ 1, 8, 10, 12 ]
# Influencing indexes for node 14 :  [ 1 ]
# Influencing indexes for node 15 :  [ 0, 5, 9, 10 ]
# Influencing indexes for node 16 :  [ 5, 7, 13, 14 ]
# Influencing indexes for node 17 :  [ 0, 15 ]
# Influencing indexes for node 18 :  [ 0, 2, 3, 7, 8, 9, 10, 13, 15 ]
# Influencing indexes for node 19 :  [ 14, 18 ]
# Influencing indexes for node 20 :  [ 4, 5, 6, 10, 16 ]
# Influencing indexes for node 21 :  [ 1, 4, 6, 8, 10, 12, 15 ]
# Influencing indexes for node 22 :  [ 1, 2, 6, 11 ]
# Influencing indexes for node 23 :  [ 5, 10, 11, 12, 13, 14, 16, 21, 22 ]
# Influencing indexes for node 24 :  [ 1, 10, 18 ]
# Influencing indexes for node 25 :  [ 0, 1, 4, 6, 12, 13, 14, 20, 22 ]
# Influencing indexes for node 26 :  [ 0, 8, 9, 11, 15, 17, 21, 23 ]
# Influencing indexes for node 27 :  [ 1, 2, 5, 7, 10, 11, 13, 15, 17, 24 ]
# Influencing indexes for node 28 :  [ 1, 2, 8, 11, 13, 17, 20, 24, 25 ]
# Influencing indexes for node 29 :  [ 1, 15, 20, 21, 22, 26 ]
# Influencing indexes for node 30 :  [ 1, 4, 8, 9, 14, 24 ]
# Influencing indexes for node 31 :  [ 4, 9, 14, 15, 16, 19, 20, 26, 30 ]
# Influencing indexes for node 32 :  [ 1, 5, 7, 9, 10, 14, 15, 21, 25, 27, 31 ]
# Influencing indexes for node 33 :  [ 4, 10, 11, 15, 16, 17, 20, 22, 24, 25, 27, 32 ]
# Influencing indexes for node 34 :  [ 2, 3, 4, 6, 7, 9, 10, 12, 13, 16, 17, 19, 20, 23, 25, 26, 29, 31, 32 ]
# Influencing indexes for node 35 :  [ 2, 3, 4, 6, 11, 15, 17, 18, 19, 20, 21, 23, 26, 29, 32 ]
# Influencing indexes for node 36 :  [ 2, 8, 12, 13, 15, 16, 17, 21, 25, 26, 27, 32, 33, 35 ]
# Influencing indexes for node 37 :  [ 4, 6, 8, 13, 23, 28, 30, 33 ]
# Influencing indexes for node 38 :  [ 0, 7, 9, 10, 11, 18, 19, 23, 24, 26, 28, 31 ]
# Influencing indexes for node 39 :  [ 0, 4, 5, 6, 16, 17, 18, 22, 23 ]
# Influencing indexes for node 40 :  [ 3, 7, 10, 14, 17, 18, 19, 20, 23, 35, 39 ]
# Influencing indexes for node 41 :  [ 0, 1, 2, 6, 7, 10, 12, 16, 17, 18, 19, 20, 30, 39 ]
# Influencing indexes for node 42 :  [ 5, 7, 8, 10, 13, 20, 24, 25, 27, 30, 31, 35, 36, 38, 40 ]
# Influencing indexes for node 43 :  [ 2, 3, 6, 9, 14, 16, 19, 22, 23, 27, 28, 31, 32, 36 ]
# Influencing indexes for node 44 :  [ 3, 28, 29, 31, 32, 35, 37, 40 ]
# Influencing indexes for node 45 :  [ 4, 8, 15, 19, 27, 30, 32, 37, 38, 43 ]
# Influencing indexes for node 46 :  [ 1, 2, 3, 4, 6, 14, 17, 18, 26, 27, 32 ]
# Influencing indexes for node 47 :  [ 0,
#   1,
#   4,
#   6,
#   7,
#   8,
#   9,
#   13,
#   16,
#   17,
#   19,
#   21,
#   22,
#   25,
#   32,
#   34,
#   35,
#   37,
#   39,
#   40,
#   42,
#   43,
#   44 ]
# Influencing indexes for node 48 :  [ 6, 8, 11, 14, 16, 19, 23, 24, 26, 27, 37, 44, 45 ]
# Influencing indexes for node 49 :  [ 3, 7, 10, 11, 12, 13, 25, 26, 27, 28, 33, 35, 38, 39, 42, 43 ]
#
# Number of nodes whose opinion didnt matter:  41
# Number of nodes who changed opinion towards the crowd:  10
# RED URN
# ./results.csv
# Node : 0 sees red
# Looking at his neighbours sees {}
# mantained his decision:  red
# Node 0 decides:  red
#
# Node : 1 sees blue
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  blue
# Node 1 decides:  blue
#
# Node : 2 sees red
# ...
# Node 23 decides:  red
#
# Node : 24 sees red
# Looking at his neighbours sees { red: 7 }
# mantained his decision:  red
# Node 24 decides:  red
#
# Node : 25 sees red
# Looking at his neighbours sees { blue: 1, red: 5 }
# mantained his decision:  red
# Node 25 decides:  red
#
# Node : 26 sees red
# Looking at his neighbours sees { red: 3, blue: 1 }
# mantained his decision:  red
# Node 26 decides:  red
#
# Node : 27 sees blue
# Looking at his neighbours sees { red: 6 }
# it has been influenced towards:  red
# Node 27 decides:  red
#
# Node : 28 sees red
# Looking at his neighbours sees { red: 9 }
# mantained his decision:  red
# Node 28 decides:  red
#
# Node : 29 sees red
# Looking at his neighbours sees { blue: 1, red: 6 }
# mantained his decision:  red
# Node 29 decides:  red
#
# Node : 30 sees red
# Looking at his neighbours sees { red: 5 }
# mantained his decision:  red
# Node 30 decides:  red
#
# Node : 31 sees blue
# Looking at his neighbours sees { red: 7, blue: 1 }
# it has been influenced towards:  red
# Node 31 decides:  red
#
# Node : 32 sees blue
# Looking at his neighbours sees { blue: 1, red: 7 }
# it has been influenced towards:  red
# Node 32 decides:  red
#
# Node : 33 sees red
# Looking at his neighbours sees { blue: 1, red: 8 }
# mantained his decision:  red
# Node 33 decides:  red
#
# Node : 34 sees red
# Looking at his neighbours sees { blue: 2, red: 7 }
# mantained his decision:  red
# Node 34 decides:  red
#
# Node : 35 sees blue
# Looking at his neighbours sees { blue: 2, red: 7 }
# it has been influenced towards:  red
# Node 35 decides:  red
#
# Node : 36 sees red
# Looking at his neighbours sees { red: 6 }
# mantained his decision:  red
# Node 36 decides:  red
#
# Node : 37 sees red
# Looking at his neighbours sees { red: 10, blue: 1 }
# mantained his decision:  red
# Node 37 decides:  red
#
# Node : 38 sees blue
# Looking at his neighbours sees { red: 12, blue: 1 }
# it has been influenced towards:  red
# Node 38 decides:  red
#
# Node : 39 sees red
# Looking at his neighbours sees { blue: 1, red: 7 }
# mantained his decision:  red
# Node 39 decides:  red
#
# Node : 40 sees blue
# Looking at his neighbours sees { red: 7 }
# it has been influenced towards:  red
# Node 40 decides:  red
#
# Node : 41 sees red
# Looking at his neighbours sees { red: 11, blue: 1 }
# mantained his decision:  red
# Node 41 decides:  red
#
# Node : 42 sees red
# Looking at his neighbours sees { red: 15 }
# mantained his decision:  red
# Node 42 decides:  red
#
# Node : 43 sees blue
# Looking at his neighbours sees { red: 14 }
# it has been influenced towards:  red
# Node 43 decides:  red
#
# Node : 44 sees red
# Looking at his neighbours sees { red: 14, blue: 1 }
# mantained his decision:  red
# Node 44 decides:  red
#
# Node : 45 sees red
# Looking at his neighbours sees { red: 18 }
# mantained his decision:  red
# Node 45 decides:  red
#
# Node : 46 sees red
# Looking at his neighbours sees { blue: 2, red: 15 }
# mantained his decision:  red
# Node 46 decides:  red
#
# Node : 47 sees blue
# Looking at his neighbours sees { red: 11, blue: 1 }
# it has been influenced towards:  red
# Node 47 decides:  red
#
# Node : 48 sees red
# Looking at his neighbours sees { blue: 1, red: 16 }
# mantained his decision:  red
# Node 48 decides:  red
#
# Node : 49 sees blue
# Looking at his neighbours sees { blue: 2, red: 10 }
# it has been influenced towards:  red
# Node 49 decides:  red
#
# ********* Statistics Summary *********
#
#
# Influencing indexes for node 0 :  []
# Influencing indexes for node 1 :  []
# Influencing indexes for node 2 :  [ 0 ]
# Influencing indexes for node 3 :  [ 0 ]
# Influencing indexes for node 4 :  []
# Influencing indexes for node 5 :  [ 3 ]
# Influencing indexes for node 6 :  [ 0, 3 ]
# Influencing indexes for node 7 :  [ 0, 6 ]
# Influencing indexes for node 8 :  [ 1, 7 ]
# Influencing indexes for node 9 :  [ 0, 1, 2, 3, 4, 5, 8 ]
# Influencing indexes for node 10 :  [ 0 ]
# Influencing indexes for node 11 :  [ 1, 2, 6 ]
# Influencing indexes for node 12 :  [ 1, 2, 9 ]
# Influencing indexes for node 13 :  [ 6, 7, 11, 12 ]
# Influencing indexes for node 14 :  [ 2, 8 ]
# Influencing indexes for node 15 :  [ 1, 2, 4, 6, 9 ]
# Influencing indexes for node 16 :  [ 1, 2, 5, 6, 7, 10, 11 ]
# Influencing indexes for node 17 :  [ 4, 9, 11, 12, 16 ]
# Influencing indexes for node 18 :  [ 2, 10, 11, 12 ]
# Influencing indexes for node 19 :  [ 0, 2, 3, 13, 15, 17 ]
# Influencing indexes for node 20 :  [ 4, 5, 6, 10, 13, 17, 18 ]
# Influencing indexes for node 21 :  [ 3, 5, 9, 10, 12, 14, 15, 16, 19, 20 ]
# Influencing indexes for node 22 :  [ 1, 5, 6, 9, 10, 12, 15, 19 ]
# Influencing indexes for node 23 :  [ 1, 2, 4, 5, 10, 14 ]
# Influencing indexes for node 24 :  [ 1, 5, 6, 15, 16, 18, 22 ]
# Influencing indexes for node 25 :  [ 8, 10, 16, 18, 21, 23 ]
# Influencing indexes for node 26 :  [ 2, 3, 8, 19 ]
# Influencing indexes for node 27 :  [ 2, 3, 5, 11, 13, 23 ]
# Influencing indexes for node 28 :  [ 4, 5, 6, 10, 13, 15, 22, 23, 24 ]
# Influencing indexes for node 29 :  [ 7, 9, 11, 13, 21, 23, 27 ]
# Influencing indexes for node 30 :  [ 3, 9, 10, 20, 24 ]
# Influencing indexes for node 31 :  [ 3, 8, 14, 20, 24, 26, 27, 29 ]
# Influencing indexes for node 32 :  [ 0, 4, 5, 12, 15, 16, 18, 19 ]
# Influencing indexes for node 33 :  [ 0, 6, 9, 15, 17, 23, 25, 27, 32 ]
# Influencing indexes for node 34 :  [ 0, 1, 8, 13, 14, 20, 29, 32, 33 ]
# Influencing indexes for node 35 :  [ 0, 1, 8, 15, 17, 19, 21, 24, 30 ]
# Influencing indexes for node 36 :  [ 5, 6, 15, 21, 27, 34 ]
# Influencing indexes for node 37 :  [ 4, 7, 9, 10, 13, 15, 20, 21, 23, 31, 35 ]
# Influencing indexes for node 38 :  [ 1, 3, 6, 8, 11, 13, 15, 17, 18, 24, 31, 34, 36 ]
# Influencing indexes for node 39 :  [ 7, 12, 15, 18, 19, 26, 33, 37 ]
# Influencing indexes for node 40 :  [ 2, 15, 17, 29, 30, 32, 35 ]
# Influencing indexes for node 41 :  [ 1, 7, 10, 14, 15, 27, 28, 29, 32, 35, 37, 38 ]
# Influencing indexes for node 42 :  [ 2, 4, 11, 15, 16, 18, 19, 20, 24, 27, 28, 29, 32, 36, 37 ]
# Influencing indexes for node 43 :  [ 6, 11, 13, 14, 16, 21, 23, 25, 26, 32, 35, 37, 38, 39 ]
# Influencing indexes for node 44 :  [ 3, 5, 6, 8, 12, 18, 23, 26, 27, 29, 30, 32, 36, 41, 43 ]
# Influencing indexes for node 45 :  [ 1, 6, 11, 13, 14, 15, 21, 23, 25, 27, 28, 30, 33, 37, 40, 42, 43, 44 ]
# Influencing indexes for node 46 :  [ 0, 3, 6, 8, 11, 14, 20, 23, 29, 30, 32, 34, 35, 36, 37, 41, 43 ]
# Influencing indexes for node 47 :  [ 3, 8, 10, 11, 15, 26, 27, 33, 34, 35, 42, 46 ]
# Influencing indexes for node 48 :  [ 0, 3, 5, 6, 13, 14, 15, 17, 19, 24, 28, 29, 34, 37, 39, 43, 47 ]
# Influencing indexes for node 49 :  [ 0, 2, 6, 7, 13, 14, 19, 22, 23, 39, 45, 46 ]
#
# Number of nodes whose opinion didnt matter:  39
# Number of nodes who changed opinion towards the crowd:  14
# BLUE URN
# ./results.csv
# Node : 0 sees red
# Looking at his neighbours sees {}
# mantained his decision:  red
# Node 0 decides:  red
#
# Node : 1 sees blue
# Looking at his neighbours sees {}
# mantained his decision:  blue
# Node 1 decides:  blue
#
# Node : 2 sees blue
# Looking at his neighbours sees {}
# mantained his decision:  blue
# Node 2 decides:  blue
#
# Node : 3 sees blue
# Looking at his neighbours sees { blue: 1 }
# mantained his decision:  blue
# Node 3 decides:  blue
#
# Node : 4 sees blue
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  blue
# Node 4 decides:  blue
#
# Node : 5 sees red
# Looking at his neighbours sees { blue: 2 }
# it has been influenced towards:  blue
# Node 5 decides:  blue
#
# Node : 6 sees blue
# Looking at his neighbours sees { blue: 2 }
# mantained his decision:  blue
# Node 6 decides:  blue
#
# Node : 7 sees blue
# Looking at his neighbours sees { blue: 3 }
# mantained his decision:  blue
# Node 7 decides:  blue
#
# Node : 8 sees blue
# Looking at his neighbours sees { blue: 3 }
# mantained his decision:  blue
# Node 8 decides:  blue
#
# Node : 9 sees blue
# Looking at his neighbours sees { blue: 1 }
# mantained his decision:  blue
# Node 9 decides:  blue
#
# Node : 10 sees blue
# Looking at his neighbours sees { red: 1, blue: 3 }
# mantained his decision:  blue
# Node 10 decides:  blue
#
# Node : 11 sees blue
# Looking at his neighbours sees { red: 1, blue: 3 }
# mantained his decision:  blue
# Node 11 decides:  blue
#
# Node : 12 sees red
# Looking at his neighbours sees { blue: 6 }
# it has been influenced towards:  blue
# Node 12 decides:  blue
#
# Node : 13 sees blue
# Looking at his neighbours sees { blue: 5 }
# mantained his decision:  blue
# Node 13 decides:  blue
#
# Node : 14 sees blue
# Looking at his neighbours sees { red: 1, blue: 4 }
# mantained his decision:  blue
# Node 14 decides:  blue
#
# Node : 15 sees red
# Looking at his neighbours sees { blue: 4 }
# it has been influenced towards:  blue
# Node 15 decides:  blue
#
# Node : 16 sees blue
# Looking at his neighbours sees { blue: 4 }
# mantained his decision:  blue
# Node 16 decides:  blue
#
# Node : 17 sees blue
# Looking at his neighbours sees { blue: 3 }
# mantained his decision:  blue
# Node 17 decides:  blue
#
# Node : 18 sees blue
# Looking at his neighbours sees { red: 1, blue: 5 }
# mantained his decision:  blue
# Node 18 decides:  blue
#
# Node : 19 sees blue
# Looking at his neighbours sees { red: 1, blue: 7 }
# mantained his decision:  blue
# Node 19 decides:  blue
#
# Node : 20 sees blue
# Looking at his neighbours sees { red: 1, blue: 4 }
# mantained his decision:  blue
# Node 20 decides:  blue
#
# Node : 21 sees blue
# Looking at his neighbours sees { red: 1, blue: 7 }
# mantained his decision:  blue
# Node 21 decides:  blue
#
# Node : 22 sees blue
# Looking at his neighbours sees { red: 1, blue: 6 }
# mantained his decision:  blue
# Node 22 decides:  blue
#
# Node : 23 sees blue
# Looking at his neighbours sees { blue: 5 }
# mantained his decision:  blue
# Node 23 decides:  blue
#
# Node : 24 sees blue
# Looking at his neighbours sees { blue: 4 }
# mantained his decision:  blue
# Node 24 decides:  blue
#
# Node : 25 sees red
# Looking at his neighbours sees { blue: 7 }
# it has been influenced towards:  blue
# Node 25 decides:  blue
#
# Node : 26 sees blue
# Looking at his neighbours sees { blue: 10 }
# mantained his decision:  blue
# Node 26 decides:  blue
#
# Node : 27 sees blue
# Looking at his neighbours sees { blue: 8 }
# mantained his decision:  blue
# Node 27 decides:  blue
#
# Node : 28 sees blue
# Looking at his neighbours sees { blue: 7 }
# mantained his decision:  blue
# Node 28 decides:  blue
#
# Node : 29 sees red
# Looking at his neighbours sees { blue: 11 }
# it has been influenced towards:  blue
# Node 29 decides:  blue
#
# Node : 30 sees red
# Looking at his neighbours sees { blue: 8 }
# it has been influenced towards:  blue
# Node 30 decides:  blue
#
# Node : 31 sees blue
# Looking at his neighbours sees { blue: 10 }
# mantained his decision:  blue
# Node 31 decides:  blue
#
# Node : 32 sees blue
# Looking at his neighbours sees { blue: 7 }
# mantained his decision:  blue
# Node 32 decides:  blue
#
# Node : 33 sees blue
# Looking at his neighbours sees { blue: 14 }
# mantained his decision:  blue
# Node 33 decides:  blue
#
# Node : 34 sees blue
# Looking at his neighbours sees { blue: 8 }
# mantained his decision:  blue
# Node 34 decides:  blue
#
# Node : 35 sees blue
# Looking at his neighbours sees { blue: 9 }
# mantained his decision:  blue
# Node 35 decides:  blue
#
# Node : 36 sees blue
# Looking at his neighbours sees { blue: 9 }
# mantained his decision:  blue
# Node 36 decides:  blue
#
# Node : 37 sees blue
# Looking at his neighbours sees { red: 1, blue: 11 }
# mantained his decision:  blue
# Node 37 decides:  blue
#
# Node : 38 sees blue
# Looking at his neighbours sees { blue: 13 }
# mantained his decision:  blue
# Node 38 decides:  blue
#
# Node : 39 sees blue
# Looking at his neighbours sees { blue: 12 }
# mantained his decision:  blue
# Node 39 decides:  blue
#
# Node : 40 sees blue
# Looking at his neighbours sees { blue: 8 }
# mantained his decision:  blue
# Node 40 decides:  blue
#
# Node : 41 sees red
# Looking at his neighbours sees { red: 1, blue: 14 }
# it has been influenced towards:  blue
# Node 41 decides:  blue
#
# Node : 42 sees blue
# Looking at his neighbours sees { red: 1, blue: 15 }
# mantained his decision:  blue
# Node 42 decides:  blue
#
# Node : 43 sees blue
# Looking at his neighbours sees { blue: 17 }
# mantained his decision:  blue
# Node 43 decides:  blue
#
# Node : 44 sees blue
# Looking at his neighbours sees { blue: 12 }
# mantained his decision:  blue
# Node 44 decides:  blue
#
# Node : 45 sees blue
# Looking at his neighbours sees { blue: 8 }
# mantained his decision:  blue
# Node 45 decides:  blue
#
# Node : 46 sees blue
# Looking at his neighbours sees { blue: 15 }
# mantained his decision:  blue
# Node 46 decides:  blue
#
# Node : 47 sees blue
# Looking at his neighbours sees { blue: 20 }
# mantained his decision:  blue
# Node 47 decides:  blue
#
# Node : 48 sees blue
# Looking at his neighbours sees { red: 1, blue: 11 }
# mantained his decision:  blue
# Node 48 decides:  blue
#
# Node : 49 sees blue
# Looking at his neighbours sees { red: 1, blue: 13 }
# mantained his decision:  blue
# Node 49 decides:  blue
#
# ********* Statistics Summary *********
#
#
# Influencing indexes for node 0 :  []
# Influencing indexes for node 1 :  []
# Influencing indexes for node 2 :  []
# Influencing indexes for node 3 :  [ 2 ]
# Influencing indexes for node 4 :  [ 0 ]
# Influencing indexes for node 5 :  [ 1, 4 ]
# Influencing indexes for node 6 :  [ 1, 3 ]
# Influencing indexes for node 7 :  [ 2, 3, 6 ]
# Influencing indexes for node 8 :  [ 1, 3, 4 ]
# Influencing indexes for node 9 :  [ 7 ]
# Influencing indexes for node 10 :  [ 0, 1, 4, 9 ]
# Influencing indexes for node 11 :  [ 0, 2, 5, 9 ]
# Influencing indexes for node 12 :  [ 3, 5, 6, 7, 9, 10 ]
# Influencing indexes for node 13 :  [ 2, 3, 4, 6, 12 ]
# Influencing indexes for node 14 :  [ 0, 2, 4, 6, 9 ]
# Influencing indexes for node 15 :  [ 1, 2, 4, 11 ]
# Influencing indexes for node 16 :  [ 3, 9, 10, 14 ]
# Influencing indexes for node 17 :  [ 3, 8, 15 ]
# Influencing indexes for node 18 :  [ 0, 3, 6, 10, 14, 15 ]
# Influencing indexes for node 19 :  [ 0, 3, 5, 8, 10, 13, 16, 18 ]
# Influencing indexes for node 20 :  [ 0, 3, 4, 9, 14 ]
# Influencing indexes for node 21 :  [ 0, 2, 4, 5, 11, 12, 14, 18 ]
# Influencing indexes for node 22 :  [ 0, 5, 9, 11, 16, 18, 21 ]
# Influencing indexes for node 23 :  [ 7, 8, 11, 19, 21 ]
# Influencing indexes for node 24 :  [ 1, 7, 13, 20 ]
# Influencing indexes for node 25 :  [ 3, 4, 9, 12, 15, 21, 24 ]
# Influencing indexes for node 26 :  [ 1, 3, 9, 10, 11, 14, 16, 19, 20, 24 ]
# Influencing indexes for node 27 :  [ 3, 9, 11, 16, 18, 20, 23, 24 ]
# Influencing indexes for node 28 :  [ 1, 9, 12, 13, 17, 22, 26 ]
# Influencing indexes for node 29 :  [ 2, 4, 5, 9, 10, 11, 12, 15, 16, 17, 28 ]
# Influencing indexes for node 30 :  [ 1, 2, 4, 9, 11, 16, 24, 29 ]
# Influencing indexes for node 31 :  [ 3, 7, 9, 12, 13, 18, 21, 22, 26, 28 ]
# Influencing indexes for node 32 :  [ 1, 7, 8, 10, 21, 22, 23 ]
# Influencing indexes for node 33 :  [ 3, 5, 7, 9, 10, 11, 13, 17, 18, 20, 21, 23, 24, 26 ]
# Influencing indexes for node 34 :  [ 1, 8, 14, 16, 20, 27, 28, 31 ]
# Influencing indexes for node 35 :  [ 2, 9, 12, 14, 16, 20, 29, 31, 33 ]
# Influencing indexes for node 36 :  [ 1, 8, 11, 12, 19, 20, 24, 25, 30 ]
# Influencing indexes for node 37 :  [ 0, 4, 5, 10, 12, 15, 18, 19, 22, 23, 25, 27 ]
# Influencing indexes for node 38 :  [ 1, 2, 3, 5, 6, 7, 9, 16, 18, 20, 30, 36, 37 ]
# Influencing indexes for node 39 :  [ 2, 3, 6, 9, 14, 15, 18, 19, 22, 27, 32, 33 ]
# Influencing indexes for node 40 :  [ 2, 3, 11, 13, 23, 30, 31, 34 ]
# Influencing indexes for node 41 :  [ 0, 5, 12, 13, 15, 16, 18, 21, 24, 25, 30, 31, 33, 34, 37 ]
# Influencing indexes for node 42 :  [ 0, 4, 5, 6, 7, 10, 11, 16, 19, 21, 23, 24, 28, 34, 37, 41 ]
# Influencing indexes for node 43 :  [ 1, 6, 7, 10, 11, 12, 15, 17, 20, 22, 28, 29, 31, 34, 36, 37, 38 ]
# Influencing indexes for node 44 :  [ 4, 8, 15, 16, 23, 25, 29, 33, 35, 38, 41, 42 ]
# Influencing indexes for node 45 :  [ 3, 7, 12, 14, 26, 30, 35, 44 ]
# Influencing indexes for node 46 :  [ 2, 4, 6, 7, 8, 9, 10, 12, 13, 14, 19, 21, 25, 31, 33 ]
# Influencing indexes for node 47 :  [ 2, 8, 11, 12, 14, 17, 18, 22, 23, 26, 27, 30, 32, 33, 35, 36, 40, 41, 44, 45 ]
# Influencing indexes for node 48 :  [ 0, 4, 8, 9, 14, 19, 26, 30, 31, 34, 37, 42 ]
# Influencing indexes for node 49 :  [ 0, 8, 9, 15, 16, 18, 21, 24, 32, 34, 36, 39, 45, 48 ]
#
# Number of nodes whose opinion didnt matter:  44
# Number of nodes who changed opinion towards the crowd:  7

# %%
df = pd.read_csv(filename, sep=";")
df.head()
# Out:
#   Graph type  Number of nodes  Edge chance  Opinions affected by Cascade  \
# 0     random               50          0.7                            42
# 1     random               50          0.7                            42
# 2     random               50          0.7                            43
# 3     random               50          0.7                            41
# 4     random               50          0.7                            41
#
#    Opinions Changed by Cascade
# 0                           12
# 1                           16
# 2                            8
# 3                           10
# 4                           10

# %% [markdown]
# ## Experimento 1: influencia de Edge Chance en Opiniones

# %%
filename ="./data/edgeChance.csv"
wipeResults(filename)
repetitions = 10
noLogs = 'true'
for e in np.arange(0,1.1,0.1):
    for i in range(repetitions):
        # !node index $filename $e $noLogs

# %%
df = pd.read_csv(filename, sep=";")
df.head(10)
# Out:
#   Graph type  Number of nodes  Edge chance  Opinions affected by Cascade  \
# 0     random               50          0.0                            47
# 1     random               50          0.1                            47
# 2     random               50          0.2                            47
# 3     random               50          0.3                            48
# 4     random               50          0.4                            46
# 5     random               50          0.5                            44
# 6     random               50          0.6                            44
# 7     random               50          0.7                            43
# 8     random               50          0.8                            36
# 9     random               50          0.9                            24
#
#    Opinions Changed by Cascade
# 0                           29
# 1                           10
# 2                           11
# 3                           11
# 4                           13
# 5                           12
# 6                           14
# 7                           15
# 8                           14
# 9                            7

# %%
edgeChanceDf = df.copy()
groupDf = edgeChanceDf.groupby("Edge chance").mean()
groupDf.plot()

# %% [markdown]
# ## Experimento 2: Relacion entre numero de nodos y Opiniones

# %%
filename ="./data/numberOfNodes.csv"
wipeResults(filename)
repetitions = 10
noLogs = 'true'
edgeChance = 0.3
for n in np.arange(50,500,50):
    for i in range(repetitions):
        # !node index $filename $edgeChance $noLogs $n
# Out:
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3

# %%
df = pd.read_csv(filename, sep=";")
numberOfNodesDf = df.copy()
numberOfNodesDf[['Opinions Changed by Cascade %']] = numberOfNodesDf[['Opinions Changed by Cascade']].div(numberOfNodesDf['Number of nodes'].values, axis=0)
groupDf = numberOfNodesDf.groupby("Number of nodes").mean()
groupDf.head()
groupDf[["Opinions Changed by Cascade","Opinions "]].plot()
# Out:
#                  Edge chance  Opinions affected by Cascade  \
# Number of nodes
# 50                       0.3                          47.4
# 100                      0.3                          96.5
# 150                      0.3                         146.7
# 200                      0.3                         196.7
# 250                      0.3                         246.7
#
#                  Opinions Changed by Cascade  Opinions Changed by Cascade %
# Number of nodes
# 50                                      21.3                       0.426000
# 100                                     40.9                       0.409000
# 150                                     60.1                       0.400667
# 200                                     79.0                       0.395000
# 250                                    120.5                       0.482000

# %% [markdown]
# #### Cambia el porcentaje?

# %%
groupDf[["Opinions Changed by Cascade %"]].plot()
