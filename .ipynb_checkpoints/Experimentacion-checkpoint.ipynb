# %% [markdown]
# # Information Cascades en Grafos

# %%
import pandas as pd
import numpy as np

# %%
filename = "./results.csv"
def wipeResults(filename):
    f = open(filename,"w+")
    f.write("Graph type;Number of nodes;Edge chance;Opinions affected by Cascade;Opinions Changed by Cascade;Exploration Mode\n")

# %% [markdown]
# ## Experimento 1: influencia de Edge Chance en Opiniones

# %%
filename ="./data/edgeChance.csv"
wipeResults(filename)
repetitions = 10
noLogs = 'true'
numberOfNodes = 50
for e in np.arange(0,1.1,0.1):
    for i in range(repetitions):
        # !node index $filename $e $noLogs $numberOfNodes

# %%
df = pd.read_csv(filename, sep=";")
df.head(11)
# Out:
#    Graph type  Number of nodes  Edge chance  Opinions affected by Cascade  \
# 0      random               50          0.0                             0
# 1      random               50          0.1                            30
# 2      random               50          0.2                            46
# 3      random               50          0.3                            47
# 4      random               50          0.4                            43
# 5      random               50          0.5                            48
# 6      random               50          0.6                            48
# 7      random               50          0.7                            47
# 8      random               50          0.8                            48
# 9      random               50          0.9                            47
# 10     random               50          1.0                            47
#
#     Opinions Changed by Cascade Exploration Mode
# 0                             0              bfs
# 1                             2              bfs
# 2                            15              bfs
# 3                            13              bfs
# 4                            12              bfs
# 5                            14              bfs
# 6                            36              bfs
# 7                            23              bfs
# 8                            16              bfs
# 9                            29              bfs
# 10                           11              bfs

# %%
edgeChanceDf = df.copy()
groupDf = edgeChanceDf.groupby("Edge chance").mean()
groupDf[["Opinions affected by Cascade","Opinions Changed by Cascade"]].plot()

# %% [markdown]
# ## Experimento 2: Relacion entre numero de nodos y Opiniones

# %%
filename ="./data/numberOfNodes.csv"
wipeResults(filename)
repetitions = 20
noLogs = 'true'
edgeChance = 0.3
for n in np.arange(50,501,50):
    for i in range(repetitions):
        # !node index $filename $edgeChance $noLogs $n

# %%
df = pd.read_csv(filename, sep=";")
numberOfNodesDf = df.copy()
numberOfNodesDf[['Opinions Changed by Cascade %']] = numberOfNodesDf[['Opinions Changed by Cascade']].div(numberOfNodesDf['Number of nodes'].values, axis=0)
groupDf = numberOfNodesDf.groupby("Number of nodes").mean()
groupDf[["Opinions Changed by Cascade","Opinions affected by Cascade"]].plot()

# %% [markdown]
# #### Cambia el porcentaje?

# %%
groupDf[["Opinions Changed by Cascade %"]].plot()

# %% [markdown]
# ### Experimento 3: Analisis cualitativo del grafo

# %%
import matplotlib.pyplot as plt
import networkx as nx

# %%
# !node index.js
# Out:
# RED URN
# Node : 0 sees red
# Looking at his neighbours sees {}
# mantained his decision:  red
# Node 0 decides:  red
#
# BFS queue:  [ 2, 5, 6, 7, 10, 11, 13 ]
# Node : 2 sees blue
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  blue
# Node 2 decides:  blue
#
# BFS queue:  [ 5, 6, 7, 10, 11, 13, 3, 4, 12 ]
# Node : 5 sees red
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  red
# Node 5 decides:  red
#
# BFS queue:  [ 6, 7, 10, 11, 13, 3, 4, 12, 1, 8 ]
# Node : 6 sees red
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  red
# Node 6 decides:  red
#
# BFS queue:  [ 7, 10, 11, 13, 3, 4, 12, 1, 8, 9 ]
# Node : 7 sees blue
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  blue
# Node 7 decides:  blue
#
# BFS queue:  [ 10, 11, 13, 3, 4, 12, 1, 8, 9 ]
# Node : 10 sees red
# Looking at his neighbours sees { red: 1, blue: 1 }
# mantained his decision:  red
# Node 10 decides:  red
#
# BFS queue:  [ 11, 13, 3, 4, 12, 1, 8, 9 ]
# Node : 11 sees blue
# Looking at his neighbours sees { red: 1, blue: 1 }
# mantained his decision:  blue
# Node 11 decides:  blue
#
# BFS queue:  [ 13, 3, 4, 12, 1, 8, 9 ]
# Node : 13 sees red
# Looking at his neighbours sees { red: 1, blue: 1 }
# mantained his decision:  red
# Node 13 decides:  red
#
# BFS queue:  [ 3, 4, 12, 1, 8, 9 ]
# Node : 3 sees red
# Looking at his neighbours sees { blue: 2, red: 1 }
# mantained his decision:  red
# Node 3 decides:  red
#
# BFS queue:  [ 4, 12, 1, 8, 9 ]
# Node : 4 sees red
# Looking at his neighbours sees { blue: 2, red: 2 }
# mantained his decision:  red
# Node 4 decides:  red
#
# BFS queue:  [ 12, 1, 8, 9, 14 ]
# Node : 12 sees blue
# Looking at his neighbours sees { blue: 1, red: 3 }
# it has been influenced towards:  red
# Node 12 decides:  red
#
# BFS queue:  [ 1, 8, 9, 14 ]
# Node : 1 sees red
# Looking at his neighbours sees { red: 3, blue: 1 }
# mantained his decision:  red
# Node 1 decides:  red
#
# BFS queue:  [ 8, 9, 14 ]
# Node : 8 sees blue
# Looking at his neighbours sees { red: 4, blue: 2 }
# it has been influenced towards:  red
# Node 8 decides:  red
#
# BFS queue:  [ 9, 14 ]
# Node : 9 sees blue
# Looking at his neighbours sees { red: 4, blue: 2 }
# it has been influenced towards:  red
# Node 9 decides:  red
#
# BFS queue:  [ 14 ]
# Node : 14 sees red
# Looking at his neighbours sees { red: 2 }
# mantained his decision:  red
# Node 14 decides:  red
#
# ********* Statistics Summary *********
#
#
# Influencing indexes for node 0 :  []
# Influencing indexes for node 1 :  [ 4, 5, 7, 12 ]
# Influencing indexes for node 2 :  [ 0 ]
# Influencing indexes for node 3 :  [ 2, 11, 13 ]
# Influencing indexes for node 4 :  [ 2, 6, 10, 11 ]
# Influencing indexes for node 5 :  [ 0 ]
# Influencing indexes for node 6 :  [ 0 ]
# Influencing indexes for node 7 :  [ 0 ]
# Influencing indexes for node 8 :  [ 3, 4, 5, 7, 11, 13 ]
# Influencing indexes for node 9 :  [ 1, 3, 6, 7, 8, 11 ]
# Influencing indexes for node 10 :  [ 0, 2 ]
# Influencing indexes for node 11 :  [ 0, 2 ]
# Influencing indexes for node 12 :  [ 2, 5, 10, 13 ]
# Influencing indexes for node 13 :  [ 0, 2 ]
# Influencing indexes for node 14 :  [ 1, 4 ]
#
# Number of nodes whose opinion didnt matter:  7
# Number of nodes who changed opinion towards the crowd:  3

# %%
f = open("./graphInfo",'r')
# print(f.read())
[nodes,edges,decisions] = f.read().split(';')
nodes = nodes.split(',')
edges = edges.split('-')
decisions = decisions.split(',')
for i in range(len(nodes)):
    nodes[i] = eval(nodes[i])

for i in range(len(edges)):
    edges[i] = eval(edges[i])
    
for i in range(len(edges)):
    if(edges[i][1] == 7):
        print("Ejes:",edges[i])
G = nx.DiGraph()
G.add_nodes_from(nodes)
G.add_edges_from(edges)
plt.figure(figsize=(15,8))
nx.draw_spring(G, node_color=decisions, with_labels=True, font_weight='bold', edge_color='grey',node_size=700)


# Descomentar para dibujar en circulo
# nx.draw_circular(G, node_color=decisions, with_labels=True, font_weight='bold', edge_color='grey',node_size=700)
# plt.savefig("graph.png")
# Out:
# Ejes: (1, 7)
# Ejes: (5, 7)
# Ejes: (8, 7)
# Ejes: (9, 7)

# %% [markdown]
# ## Experimento 4: Diferencia en resultados entre recorridos bfs y random

# %%
filename ="./data/recorridos.csv"
wipeResults(filename)
repetitions = 20
noLogs = 'true'
edgeChance = 0.3
numberOfNodes = 50
graphFileName = './graphInfo'
for numberOfNodes in np.arange(50,501,50):
    for explorationMode in ['bfs','random']:
        for i in range(repetitions):
            # !node index $filename $edgeChance $noLogs $numberOfNodes $graphFileName $explorationMode

# %%
df = pd.read_csv("./data/recorridos.csv", sep=";")
df.head(21)
# Out:
#    Graph type  Number of nodes  Edge chance  Opinions affected by Cascade  \
# 0      random               50          0.3                            44
# 1      random               50          0.3                            45
# 2      random               50          0.3                            45
# 3      random               50          0.3                            43
# 4      random               50          0.3                            43
# 5      random               50          0.3                            45
# 6      random               50          0.3                            45
# 7      random               50          0.3                            44
# 8      random               50          0.3                            46
# 9      random               50          0.3                            44
# 10     random               50          0.3                            44
# 11     random               50          0.3                            47
# 12     random               50          0.3                            46
# 13     random               50          0.3                            44
# 14     random               50          0.3                            44
# 15     random               50          0.3                            43
# 16     random               50          0.3                            44
# 17     random               50          0.3                            43
# 18     random               50          0.3                            46
# 19     random               50          0.3                            46
# 20     random               50          0.3                            43
#
#     Opinions Changed by Cascade Exploration Mode
# 0                            12              bfs
# 1                            12              bfs
# 2                            20              bfs
# 3                            12              bfs
# 4                             6              bfs
# 5                            18              bfs
# 6                            17              bfs
# 7                            12              bfs
# 8                            13              bfs
# 9                            34              bfs
# 10                           15              bfs
# 11                           17              bfs
# 12                           17              bfs
# 13                            6              bfs
# 14                           23              bfs
# 15                            9              bfs
# 16                           19              bfs
# 17                           14              bfs
# 18                           17              bfs
# 19                           14              bfs
# 20                           21           random

# %%
dfRecorridos = df.copy()
dfRecorridos = dfRecorridos.groupby(["Exploration Mode","Number of nodes"]).mean()
dfRecorridos.head(20)
# Out:
#                                   Edge chance  Opinions affected by Cascade  \
# Exploration Mode Number of nodes
# bfs              50                       0.3                         44.55
#                  100                      0.3                         94.30
#                  150                      0.3                        144.60
#                  200                      0.3                        194.35
#                  250                      0.3                        245.70
#                  300                      0.3                        294.35
#                  350                      0.3                        344.40
#                  400                      0.3                        394.40
#                  450                      0.3                        443.90
#                  500                      0.3                        494.85
# random           50                       0.3                         42.70
#                  100                      0.3                         91.80
#                  150                      0.3                        141.75
#                  200                      0.3                        192.05
#                  250                      0.3                        242.30
#                  300                      0.3                        291.95
#                  350                      0.3                        341.70
#                  400                      0.3                        392.55
#                  450                      0.3                        442.35
#                  500                      0.3                        492.15
#
#                                   Opinions Changed by Cascade
# Exploration Mode Number of nodes
# bfs              50                                     15.35
#                  100                                    38.55
#                  150                                    48.50
#                  200                                    73.75
#                  250                                    94.65
#                  300                                   120.50
#                  350                                   119.40
#                  400                                   137.10
#                  450                                   159.90
#                  500                                   205.75
# random           50                                     13.85
#                  100                                    34.85
#                  150                                    50.15
#                  200                                    63.45
#                  250                                    78.25
#                  300                                    97.00
#                  350                                   117.80
#                  400                                   137.50
#                  450                                   162.80
#                  500                                   190.70

# %%
fig,a = plt.subplots(1,1)
# ax.plot(dfRecorridos.index.levels[1], dfRecorridos.index.levels[1])
dfRecorridos.xs('bfs').plot("Opinions affected by Cascade",ax=a)
dfRecorridos.xs('random').plot("Opinions affected by Cascade",ax=a)
