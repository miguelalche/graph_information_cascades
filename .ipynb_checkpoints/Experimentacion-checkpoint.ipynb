# %% [markdown]
# # Information Cascades en Grafos

# %%
import pandas as pd
import numpy as np

# %%
filename = "./results.csv"
def wipeResults(filename):
    f = open(filename,"w+")
    f.write("Graph type;Number of nodes;Edge chance;Opinions affected by Cascade;Opinions Changed by Cascade;Exploration Mode\n")

# %% [markdown]
# ## Experimento 1: influencia de Edge Chance en Opiniones

# %%
filename ="./data/edgeChance.csv"
wipeResults(filename)
repetitions = 10
noLogs = 'true'
numberOfNodes = 50
for e in np.arange(0,1.1,0.1):
    for i in range(repetitions):
        # !node index $filename $e $noLogs $numberOfNodes

# %%
df = pd.read_csv(filename, sep=";")
df.head(11)
# Out:
#    Graph type  Number of nodes  Edge chance  Opinions affected by Cascade  \
# 0      random               50          0.0                             0
# 1      random               50          0.1                            30
# 2      random               50          0.2                            46
# 3      random               50          0.3                            47
# 4      random               50          0.4                            43
# 5      random               50          0.5                            48
# 6      random               50          0.6                            48
# 7      random               50          0.7                            47
# 8      random               50          0.8                            48
# 9      random               50          0.9                            47
# 10     random               50          1.0                            47
#
#     Opinions Changed by Cascade Exploration Mode
# 0                             0              bfs
# 1                             2              bfs
# 2                            15              bfs
# 3                            13              bfs
# 4                            12              bfs
# 5                            14              bfs
# 6                            36              bfs
# 7                            23              bfs
# 8                            16              bfs
# 9                            29              bfs
# 10                           11              bfs

# %%
edgeChanceDf = df.copy()
groupDf = edgeChanceDf.groupby("Edge chance").mean()
groupDf[["Opinions affected by Cascade","Opinions Changed by Cascade"]].plot()

# %% [markdown]
# ## Experimento 2: Relacion entre numero de nodos y Opiniones

# %%
filename ="./data/numberOfNodes.csv"
wipeResults(filename)
repetitions = 20
noLogs = 'true'
edgeChance = 0.3
for n in np.arange(50,501,50):
    for i in range(repetitions):
        # !node index $filename $edgeChance $noLogs $n

# %%
df = pd.read_csv(filename, sep=";")
numberOfNodesDf = df.copy()
numberOfNodesDf[['Opinions Changed by Cascade %']] = numberOfNodesDf[['Opinions Changed by Cascade']].div(numberOfNodesDf['Number of nodes'].values, axis=0)
groupDf = numberOfNodesDf.groupby("Number of nodes").mean()
groupDf[["Opinions Changed by Cascade","Opinions affected by Cascade"]].plot()

# %% [markdown]
# #### Cambia el porcentaje?

# %%
groupDf[["Opinions Changed by Cascade %"]].plot()

# %% [markdown]
# ### Experimento 3: Analisis cualitativo del grafo

# %%
import matplotlib.pyplot as plt
import networkx as nx

# %%
# !node index.js
# Out:
# BLUE URN
# Node : 0 sees red
# Looking at his neighbours sees {}
# mantained his decision:  red
# Node 0 decides:  red
#
# BFS queue:  [ 7, 14, 32, 33, 35, 37, 43 ]
# Node : 7 sees blue
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  blue
# Node 7 decides:  blue
#
# BFS queue:  [ 14, 32, 33, 35, 37, 43, 12, 34 ]
# Node : 14 sees blue
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  blue
# Node 14 decides:  blue
#
# BFS queue:  [ 32, 33, 35, 37, 43, 12, 34, 40, 45 ]
# Node : 32 sees blue
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  blue
# Node 32 decides:  blue
#
# BFS queue:  [ 33, 35, 37, 43, 12, 34, 40, 45, 13, 20, 23, 38, 41, 44 ]
# Node : 33 sees red
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  red
# Node 33 decides:  red
#
# BFS queue:  [ 35, 37, 43, 12, 34, 40, 45, 13, 20, 23, 38, 41, 44, 9, 11, 42 ]
# Node : 35 sees blue
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  blue
# Node 35 decides:  blue
#
# BFS queue:  [ 37,
#   43,
#   12,
#   34,
#   40,
#   45,
#   13,
#   20,
#   23,
#   38,
#   41,
#   44,
#   9,
#   11,
#   42,
#   1,
#   26,
#   29,
#   31,
#   36,
#   47 ]
# Node : 37 sees blue
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  blue
# Node 37 decides:  blue
#
# BFS queue:  [ 43,
#   12,
#   34,
#   40,
#   45,
#   13,
#   20,
#   23,
#   38,
#   41,
#   44,
#   9,
#   11,
#   42,
#   1,
#   26,
#   29,
#   31,
#   36,
#   47,
#   16 ]
# Node : 43 sees blue
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  blue
# Node 43 decides:  blue
#
# BFS queue:  [ 12,
#   34,
#   40,
#   45,
#   13,
#   20,
#   23,
#   38,
#   41,
#   44,
#   9,
#   11,
#   42,
#   1,
#   26,
#   29,
#   31,
#   36,
#   47,
#   16,
#   24 ]
# Node : 12 sees blue
# Looking at his neighbours sees { blue: 2 }
# mantained his decision:  blue
# Node 12 decides:  blue
#
# BFS queue:  [ 34,
#   40,
#   45,
#   13,
#   20,
#   23,
#   38,
#   41,
#   44,
#   9,
#   11,
#   42,
#   1,
#   26,
#   29,
#   31,
#   36,
#   47,
#   16,
#   24,
#   19 ]
# Node : 34 sees blue
# Looking at his neighbours sees { blue: 1 }
# mantained his decision:  blue
# Node 34 decides:  blue
#
# BFS queue:  [ 40, 45, 13, 20, 23, 38, 41, 44, 9, 11, 42, 1, 26, 29, 31, 36, 47, 16, 24, 19, 3 ]
# Node : 40 sees blue
# Looking at his neighbours sees { blue: 1 }
# mantained his decision:  blue
# Node 40 decides:  blue
#
# BFS queue:  [ 45,
#   13,
#   20,
#   23,
#   38,
#   41,
#   44,
#   9,
#   11,
#   42,
#   1,
#   26,
#   29,
#   31,
#   36,
#   47,
#   16,
#   24,
#   19,
#   3,
#   2,
#   21,
#   22 ]
# Node : 45 sees blue
# Looking at his neighbours sees { blue: 2, red: 1 }
# mantained his decision:  blue
# Node 45 decides:  blue
#
# BFS queue:  [ 13,
#   20,
#   23,
#   38,
#   41,
#   44,
#   9,
#   11,
#   42,
#   1,
#   26,
#   29,
#   31,
#   36,
#   47,
#   16,
#   24,
#   19,
#   3,
#   2,
#   21,
#   22 ]
# Node : 13 sees red
# Looking at his neighbours sees { blue: 2 }
# it has been influenced towards:  blue
# Node 13 decides:  blue
#
# BFS queue:  [ 20,
#   23,
#   38,
#   41,
#   44,
#   9,
#   11,
#   42,
#   1,
#   26,
#   29,
#   31,
#   36,
#   47,
#   16,
#   24,
#   19,
#   3,
#   2,
#   21,
#   22,
#   17,
#   39,
#   48 ]
# Node : 20 sees blue
# Looking at his neighbours sees { blue: 2 }
# mantained his decision:  blue
# Node 20 decides:  blue
#
# BFS queue:  [ 23,
#   38,
#   41,
#   44,
#   9,
#   11,
#   42,
#   1,
#   26,
#   29,
#   31,
#   36,
#   47,
#   16,
#   24,
#   19,
#   3,
#   2,
#   21,
#   22,
#   17,
#   39,
#   48,
#   5 ]
# Node : 23 sees blue
# Looking at his neighbours sees { blue: 2, red: 1 }
# mantained his decision:  blue
# Node 23 decides:  blue
#
# BFS queue:  [ 38,
#   41,
#   44,
#   9,
#   11,
#   42,
#   1,
#   26,
#   29,
#   31,
#   36,
#   47,
#   16,
#   24,
#   19,
#   3,
#   2,
#   21,
#   22,
#   17,
#   39,
#   48,
#   5,
#   25 ]
# Node : 38 sees blue
# Looking at his neighbours sees { blue: 2 }
# mantained his decision:  blue
# Node 38 decides:  blue
#
# BFS queue:  [ 41,
#   44,
#   9,
#   11,
#   42,
#   1,
#   26,
#   29,
#   31,
#   36,
#   47,
#   16,
#   24,
#   19,
#   3,
#   2,
#   21,
#   22,
#   17,
#   39,
#   48,
#   5,
#   25,
#   6 ]
# Node : 41 sees blue
# Looking at his neighbours sees { blue: 2 }
# mantained his decision:  blue
# Node 41 decides:  blue
#
# BFS queue:  [ 44,
#   9,
#   11,
#   42,
#   1,
#   26,
#   29,
#   31,
#   36,
#   47,
#   16,
#   24,
#   19,
#   3,
#   2,
#   21,
#   22,
#   17,
#   39,
#   48,
#   5,
#   25,
#   6,
#   18,
#   28,
#   30 ]
# Node : 44 sees red
# Looking at his neighbours sees { blue: 3 }
# it has been influenced towards:  blue
# Node 44 decides:  blue
#
# BFS queue:  [ 9,
#   11,
#   42,
#   1,
#   26,
#   29,
#   31,
#   36,
#   47,
#   16,
#   24,
#   19,
#   3,
#   2,
#   21,
#   22,
#   17,
#   39,
#   48,
#   5,
#   25,
#   6,
#   18,
#   28,
#   30 ]
# Node : 9 sees blue
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  blue
# Node 9 decides:  blue
#
# BFS queue:  [ 11,
#   42,
#   1,
#   26,
#   29,
#   31,
#   36,
#   47,
#   16,
#   24,
#   19,
#   3,
#   2,
#   21,
#   22,
#   17,
#   39,
#   48,
#   5,
#   25,
#   6,
#   18,
#   28,
#   30,
#   49 ]
# Node : 11 sees blue
# Looking at his neighbours sees { blue: 2, red: 1 }
# mantained his decision:  blue
# Node 11 decides:  blue
#
# BFS queue:  [ 42,
#   1,
#   26,
#   29,
#   31,
#   36,
#   47,
#   16,
#   24,
#   19,
#   3,
#   2,
#   21,
#   22,
#   17,
#   39,
#   48,
#   5,
#   25,
#   6,
#   18,
#   28,
#   30,
#   49,
#   8,
#   27,
#   46 ]
# Node : 42 sees blue
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  blue
# Node 42 decides:  blue
#
# BFS queue:  [ 1,
#   26,
#   29,
#   31,
#   36,
#   47,
#   16,
#   24,
#   19,
#   3,
#   2,
#   21,
#   22,
#   17,
#   39,
#   48,
#   5,
#   25,
#   6,
#   18,
#   28,
#   30,
#   49,
#   8,
#   27,
#   46 ]
# Node : 1 sees blue
# Looking at his neighbours sees { blue: 3 }
# mantained his decision:  blue
# Node 1 decides:  blue
#
# BFS queue:  [ 26,
#   29,
#   31,
#   36,
#   47,
#   16,
#   24,
#   19,
#   3,
#   2,
#   21,
#   22,
#   17,
#   39,
#   48,
#   5,
#   25,
#   6,
#   18,
#   28,
#   30,
#   49,
#   8,
#   27,
#   46,
#   15 ]
# Node : 26 sees red
# Looking at his neighbours sees { blue: 4 }
# it has been influenced towards:  blue
# Node 26 decides:  blue
#
# BFS queue:  [ 29,
#   31,
#   36,
#   47,
#   16,
#   24,
#   19,
#   3,
#   2,
#   21,
#   22,
#   17,
#   39,
#   48,
#   5,
#   25,
#   6,
#   18,
#   28,
#   30,
#   49,
#   8,
#   27,
#   46,
#   15 ]
# Node : 29 sees blue
# Looking at his neighbours sees { blue: 3 }
# mantained his decision:  blue
# Node 29 decides:  blue
#
# BFS queue:  [ 31,
#   36,
#   47,
#   16,
#   24,
#   19,
#   3,
#   2,
#   21,
#   22,
#   17,
#   39,
#   48,
#   5,
#   25,
#   6,
#   18,
#   28,
#   30,
#   49,
#   8,
#   27,
#   46,
#   15 ]
# Node : 31 sees blue
# Looking at his neighbours sees { blue: 4 }
# mantained his decision:  blue
# Node 31 decides:  blue
#
# BFS queue:  [ 36,
#   47,
#   16,
#   24,
#   19,
#   3,
#   2,
#   21,
#   22,
#   17,
#   39,
#   48,
#   5,
#   25,
#   6,
#   18,
#   28,
#   30,
#   49,
#   8,
#   27,
#   46,
#   15,
#   10 ]
# Node : 36 sees red
# Looking at his neighbours sees { blue: 2 }
# it has been influenced towards:  blue
# Node 36 decides:  blue
#
# BFS queue:  [ 47,
#   16,
#   24,
#   19,
#   3,
#   2,
#   21,
#   22,
#   17,
#   39,
#   48,
#   5,
#   25,
#   6,
#   18,
#   28,
#   30,
#   49,
#   8,
#   27,
#   46,
#   15,
#   10 ]
# Node : 47 sees blue
# Looking at his neighbours sees { blue: 2 }
# mantained his decision:  blue
# Node 47 decides:  blue
#
# BFS queue:  [ 16,
#   24,
#   19,
#   3,
#   2,
#   21,
#   22,
#   17,
#   39,
#   48,
#   5,
#   25,
#   6,
#   18,
#   28,
#   30,
#   49,
#   8,
#   27,
#   46,
#   15,
#   10 ]
# Node : 16 sees blue
# Looking at his neighbours sees { blue: 5 }
# mantained his decision:  blue
# Node 16 decides:  blue
#
# BFS queue:  [ 24, 19, 3, 2, 21, 22, 17, 39, 48, 5, 25, 6, 18, 28, 30, 49, 8, 27, 46, 15, 10 ]
# Node : 24 sees blue
# Looking at his neighbours sees { blue: 5 }
# mantained his decision:  blue
# Node 24 decides:  blue
#
# BFS queue:  [ 19, 3, 2, 21, 22, 17, 39, 48, 5, 25, 6, 18, 28, 30, 49, 8, 27, 46, 15, 10 ]
# Node : 19 sees blue
# Looking at his neighbours sees { blue: 6 }
# mantained his decision:  blue
# Node 19 decides:  blue
#
# BFS queue:  [ 3, 2, 21, 22, 17, 39, 48, 5, 25, 6, 18, 28, 30, 49, 8, 27, 46, 15, 10 ]
# Node : 3 sees blue
# Looking at his neighbours sees { blue: 3 }
# mantained his decision:  blue
# Node 3 decides:  blue
#
# BFS queue:  [ 2, 21, 22, 17, 39, 48, 5, 25, 6, 18, 28, 30, 49, 8, 27, 46, 15, 10 ]
# Node : 2 sees red
# Looking at his neighbours sees { blue: 4 }
# it has been influenced towards:  blue
# Node 2 decides:  blue
#
# BFS queue:  [ 21, 22, 17, 39, 48, 5, 25, 6, 18, 28, 30, 49, 8, 27, 46, 15, 10 ]
# Node : 21 sees blue
# Looking at his neighbours sees { blue: 3 }
# mantained his decision:  blue
# Node 21 decides:  blue
#
# BFS queue:  [ 22, 17, 39, 48, 5, 25, 6, 18, 28, 30, 49, 8, 27, 46, 15, 10 ]
# Node : 22 sees red
# Looking at his neighbours sees { blue: 2 }
# it has been influenced towards:  blue
# Node 22 decides:  blue
#
# BFS queue:  [ 17, 39, 48, 5, 25, 6, 18, 28, 30, 49, 8, 27, 46, 15, 10 ]
# Node : 17 sees blue
# Looking at his neighbours sees { blue: 3 }
# mantained his decision:  blue
# Node 17 decides:  blue
#
# BFS queue:  [ 39, 48, 5, 25, 6, 18, 28, 30, 49, 8, 27, 46, 15, 10 ]
# Node : 39 sees blue
# Looking at his neighbours sees { blue: 5 }
# mantained his decision:  blue
# Node 39 decides:  blue
#
# BFS queue:  [ 48, 5, 25, 6, 18, 28, 30, 49, 8, 27, 46, 15, 10 ]
# Node : 48 sees blue
# Looking at his neighbours sees { blue: 5 }
# mantained his decision:  blue
# Node 48 decides:  blue
#
# BFS queue:  [ 5, 25, 6, 18, 28, 30, 49, 8, 27, 46, 15, 10 ]
# Node : 5 sees red
# Looking at his neighbours sees { blue: 3 }
# it has been influenced towards:  blue
# Node 5 decides:  blue
#
# BFS queue:  [ 25, 6, 18, 28, 30, 49, 8, 27, 46, 15, 10 ]
# Node : 25 sees blue
# Looking at his neighbours sees { blue: 6 }
# mantained his decision:  blue
# Node 25 decides:  blue
#
# BFS queue:  [ 6, 18, 28, 30, 49, 8, 27, 46, 15, 10, 4 ]
# Node : 6 sees red
# Looking at his neighbours sees { blue: 5 }
# it has been influenced towards:  blue
# Node 6 decides:  blue
#
# BFS queue:  [ 18, 28, 30, 49, 8, 27, 46, 15, 10, 4 ]
# Node : 18 sees blue
# Looking at his neighbours sees { blue: 4 }
# mantained his decision:  blue
# Node 18 decides:  blue
#
# BFS queue:  [ 28, 30, 49, 8, 27, 46, 15, 10, 4 ]
# Node : 28 sees red
# Looking at his neighbours sees { blue: 2 }
# it has been influenced towards:  blue
# Node 28 decides:  blue
#
# BFS queue:  [ 30, 49, 8, 27, 46, 15, 10, 4 ]
# Node : 30 sees blue
# Looking at his neighbours sees { blue: 3 }
# mantained his decision:  blue
# Node 30 decides:  blue
#
# BFS queue:  [ 49, 8, 27, 46, 15, 10, 4 ]
# Node : 49 sees red
# Looking at his neighbours sees { blue: 4 }
# it has been influenced towards:  blue
# Node 49 decides:  blue
#
# BFS queue:  [ 8, 27, 46, 15, 10, 4 ]
# Node : 8 sees blue
# Looking at his neighbours sees { blue: 4 }
# mantained his decision:  blue
# Node 8 decides:  blue
#
# BFS queue:  [ 27, 46, 15, 10, 4 ]
# Node : 27 sees red
# Looking at his neighbours sees { blue: 6 }
# it has been influenced towards:  blue
# Node 27 decides:  blue
#
# BFS queue:  [ 46, 15, 10, 4 ]
# Node : 46 sees red
# Looking at his neighbours sees { blue: 4 }
# it has been influenced towards:  blue
# Node 46 decides:  blue
#
# BFS queue:  [ 15, 10, 4 ]
# Node : 15 sees red
# Looking at his neighbours sees { blue: 3 }
# it has been influenced towards:  blue
# Node 15 decides:  blue
#
# BFS queue:  [ 10, 4 ]
# Node : 10 sees red
# Looking at his neighbours sees { blue: 2 }
# it has been influenced towards:  blue
# Node 10 decides:  blue
#
# BFS queue:  [ 4 ]
# Node : 4 sees blue
# Looking at his neighbours sees { blue: 1 }
# mantained his decision:  blue
# Node 4 decides:  blue
#
# ********* Statistics Summary *********
#
#
# Influencing indexes for node 0 :  []
# Influencing indexes for node 1 :  [ 35, 37, 45 ]
# Influencing indexes for node 2 :  [ 9, 23, 31, 40 ]
# Influencing indexes for node 3 :  [ 1, 23, 34 ]
# Influencing indexes for node 4 :  [ 25 ]
# Influencing indexes for node 5 :  [ 20, 22, 23 ]
# Influencing indexes for node 6 :  [ 22, 26, 31, 38, 47 ]
# Influencing indexes for node 7 :  [ 0 ]
# Influencing indexes for node 8 :  [ 1, 2, 3, 11 ]
# Influencing indexes for node 9 :  [ 33 ]
# Influencing indexes for node 10 :  [ 31, 39 ]
# Influencing indexes for node 11 :  [ 12, 33, 34 ]
# Influencing indexes for node 12 :  [ 7, 32 ]
# Influencing indexes for node 13 :  [ 32, 40 ]
# Influencing indexes for node 14 :  [ 0 ]
# Influencing indexes for node 15 :  [ 1, 2, 24 ]
# Influencing indexes for node 16 :  [ 23, 34, 37, 38, 45 ]
# Influencing indexes for node 17 :  [ 13, 16, 44 ]
# Influencing indexes for node 18 :  [ 3, 9, 11, 41 ]
# Influencing indexes for node 19 :  [ 1, 9, 12, 16, 36, 42 ]
# Influencing indexes for node 20 :  [ 32, 45 ]
# Influencing indexes for node 21 :  [ 20, 26, 40 ]
# Influencing indexes for node 22 :  [ 40, 44 ]
# Influencing indexes for node 23 :  [ 32, 33, 43 ]
# Influencing indexes for node 24 :  [ 16, 20, 38, 42, 43 ]
# Influencing indexes for node 25 :  [ 16, 17, 21, 23, 24, 31 ]
# Influencing indexes for node 26 :  [ 12, 35, 40, 42 ]
# Influencing indexes for node 27 :  [ 2, 11, 21, 22, 26, 49 ]
# Influencing indexes for node 28 :  [ 41, 47 ]
# Influencing indexes for node 29 :  [ 35, 38, 44 ]
# Influencing indexes for node 30 :  [ 1, 39, 41 ]
# Influencing indexes for node 31 :  [ 1, 11, 35, 41 ]
# Influencing indexes for node 32 :  [ 0 ]
# Influencing indexes for node 33 :  [ 0 ]
# Influencing indexes for node 34 :  [ 7 ]
# Influencing indexes for node 35 :  [ 0 ]
# Influencing indexes for node 36 :  [ 20, 35 ]
# Influencing indexes for node 37 :  [ 0 ]
# Influencing indexes for node 38 :  [ 23, 32 ]
# Influencing indexes for node 39 :  [ 13, 17, 19, 36, 42 ]
# Influencing indexes for node 40 :  [ 14 ]
# Influencing indexes for node 41 :  [ 23, 32 ]
# Influencing indexes for node 42 :  [ 33 ]
# Influencing indexes for node 43 :  [ 0 ]
# Influencing indexes for node 44 :  [ 13, 23, 32 ]
# Influencing indexes for node 45 :  [ 14, 33, 40 ]
# Influencing indexes for node 46 :  [ 11, 16, 47, 49 ]
# Influencing indexes for node 47 :  [ 35, 42 ]
# Influencing indexes for node 48 :  [ 1, 13, 36, 39, 42 ]
# Influencing indexes for node 49 :  [ 2, 9, 16, 39 ]
#
# Number of nodes whose opinion didnt matter:  37
# Number of nodes who changed opinion towards the crowd:  14

# %%
f = open("./graphInfo",'r')
# print(f.read())
[nodes,edges,decisions] = f.read().split(';')
nodes = nodes.split(',')
edges = edges.split('-')
decisions = decisions.split(',')
for i in range(len(nodes)):
    nodes[i] = eval(nodes[i])

for i in range(len(edges)):
    edges[i] = eval(edges[i])
    
for i in range(len(edges)):
    if(edges[i][1] == 7):
        print("Ejes:",edges[i])
G = nx.DiGraph()
G.add_nodes_from(nodes)
G.add_edges_from(edges)
plt.figure(figsize=(15,8))
nx.draw_spring(G, node_color=decisions, with_labels=True, font_weight='bold', edge_color='grey',node_size=700)


# Descomentar para dibujar en circulo
# nx.draw_circular(G, node_color=decisions, with_labels=True, font_weight='bold', edge_color='grey',node_size=700)
# plt.savefig("graph.png")
# Out:
# Ejes: (41, 7)
# Ejes: (47, 7)

# %% [markdown]
# ## Experimento 4: Diferencia en resultados entre recorridos bfs y random

# %%
filename ="./data/recorridos.csv"
wipeResults(filename)
repetitions = 20
noLogs = 'true'
edgeChance = 0.3
numberOfNodes = 50
graphFileName = './graphInfo'
for numberOfNodes in np.arange(50,501,50):
    for explorationMode in ['bfs','random']:
        for i in range(repetitions):
            # !node index $filename $edgeChance $noLogs $numberOfNodes $graphFileName $explorationMode

# %%
df = pd.read_csv("./data/recorridos.csv", sep=";")
df.head(21)
# Out:
#    Graph type  Number of nodes  Edge chance  Opinions affected by Cascade  \
# 0      random               50          0.1                            31
# 1      random               50          0.1                            31
# 2      random               50          0.1                            32
# 3      random               50          0.1                            32
# 4      random               50          0.1                            31
# 5      random               50          0.1                            41
# 6      random               50          0.1                            36
# 7      random               50          0.1                            30
# 8      random               50          0.1                            35
# 9      random               50          0.1                            37
# 10     random               50          0.1                            31
# 11     random               50          0.1                            32
# 12     random               50          0.1                            27
# 13     random               50          0.1                            30
# 14     random               50          0.1                            38
# 15     random               50          0.1                            26
# 16     random               50          0.1                            28
# 17     random               50          0.1                            26
# 18     random               50          0.1                            27
# 19     random               50          0.1                            26
# 20     random               50          0.1                            29
#
#     Opinions Changed by Cascade Exploration Mode
# 0                            12              bfs
# 1                             8              bfs
# 2                            11              bfs
# 3                             7              bfs
# 4                             4              bfs
# 5                            10              bfs
# 6                            11              bfs
# 7                            10              bfs
# 8                             9              bfs
# 9                            10              bfs
# 10                            7              bfs
# 11                            7              bfs
# 12                            8              bfs
# 13                           12              bfs
# 14                           13              bfs
# 15                            7              bfs
# 16                           14              bfs
# 17                            9              bfs
# 18                            8              bfs
# 19                            4              bfs
# 20                           11           random

# %%
dfRecorridos = df.copy()
dfRecorridos = dfRecorridos.groupby(["Exploration Mode","Number of nodes"]).mean()
dfRecorridos.head(20)
# Out:
#                                   Edge chance  Opinions affected by Cascade  \
# Exploration Mode Number of nodes
# bfs              50                       0.1                         31.35
#                  100                      0.1                         84.55
#                  150                      0.1                        135.00
#                  200                      0.1                        184.10
#                  250                      0.1                        233.85
#                  300                      0.1                        284.50
#                  350                      0.1                        334.95
#                  400                      0.1                        385.55
#                  450                      0.1                        435.75
#                  500                      0.1                        485.20
# random           50                       0.1                         27.80
#                  100                      0.1                         76.15
#                  150                      0.1                        126.05
#                  200                      0.1                        175.50
#                  250                      0.1                        226.65
#                  300                      0.1                        275.35
#                  350                      0.1                        325.90
#                  400                      0.1                        375.95
#                  450                      0.1                        425.75
#                  500                      0.1                        476.80
#
#                                   Opinions Changed by Cascade
# Exploration Mode Number of nodes
# bfs              50                                      9.05
#                  100                                    27.05
#                  150                                    46.90
#                  200                                    59.85
#                  250                                    76.90
#                  300                                    92.95
#                  350                                   111.10
#                  400                                   127.20
#                  450                                   159.70
#                  500                                   172.90
# random           50                                      7.60
#                  100                                    22.85
#                  150                                    39.00
#                  200                                    55.05
#                  250                                    72.50
#                  300                                    87.25
#                  350                                   106.55
#                  400                                   123.20
#                  450                                   142.20
#                  500                                   157.90

# %%
fig,a = plt.subplots(1,1)
dfBFS = dfRecorridos.xs('bfs')[["Opinions Changed by Cascade", "Opinions affected by Cascade"]]
dfBFS = dfBFS.rename(columns={"Opinions Changed by Cascade":"Opinions Changed BFS", "Opinions affected by Cascade":"Opinions affected BFS"})

dfRandom = dfRecorridos.xs('random')[["Opinions Changed by Cascade", "Opinions affected by Cascade"]]
dfRandom = dfRandom.rename(columns={"Opinions Changed by Cascade":"Opinions Changed Random Exploration", "Opinions affected by Cascade":"Opinions affected Random Exploration"})

dfBFS.plot(ax=a, color='r')
dfRandom.plot(ax=a, color='b')

# %% [markdown]
# #### Probemos de nuevo, esta vez con mayor cantidad de nodos y menor edge chance y una mejor visualizacion

# %%
filename ="./data/recorridos.csv"
wipeResults(filename)
repetitions = 3
noLogs = 'true'
edgeChance = 0.001
graphFileName = './graphInfo'
for numberOfNodes in np.arange(500,6001,500):
    for explorationMode in ['bfs','random']:
        for i in range(repetitions):
            # !node index $filename $edgeChance $noLogs $numberOfNodes $graphFileName $explorationMode

# %%
df = pd.read_csv("./data/recorridos.csv", sep=";")
dfRecorridos = df.copy()
dfRecorridos = dfRecorridos.groupby(["Exploration Mode","Number of nodes"]).mean()
fig,a = plt.subplots(1,2)

dfBFS = dfRecorridos.xs('bfs')[["Opinions Changed by Cascade"]]
dfBFS = dfBFS.rename(columns={"Opinions Changed by Cascade":"Opinions Changed BFS"})

dfBFSAffected = dfRecorridos.xs('bfs')[["Opinions affected by Cascade"]]
dfBFSAffected = dfBFSAffected.rename(columns={"Opinions affected by Cascade":"Opinions affected BFS"})

dfRandom = dfRecorridos.xs('random')[["Opinions Changed by Cascade"]]
dfRandom = dfRandom.rename(columns={"Opinions Changed by Cascade":"Opinions Changed Random Exploration"})

dfRandomAffected = dfRecorridos.xs('random')[[ "Opinions affected by Cascade"]]
dfRandomAffected = dfRandomAffected.rename(columns={"Opinions affected by Cascade":"Opinions affected Random Exploration"})


dfBFS.plot(ax=a[0], color='r',figsize=(15,8))
dfRandom.plot(ax=a[0], color='b')
dfBFSAffected.plot(ax=a[1], color='r')
dfRandomAffected.plot(ax=a[1], color='b')
