# %% [markdown]
# # Information Cascades en Grafos

# %%
import pandas as pd

# %%
filename = "./results.csv"
def wipeResults():
    f = open("./results.csv","w+")
    f.write("Graph type;Number of nodes;Edge chance;Opinions affected by Cascade;Opinions Changed by Cascade;\n")

wipeResults()

# %%
# !node index $filename
# Out:
# RED URN
# ./results.csv
# Node : 0 sees red
# Looking at his neighbours sees {}
# mantained his decision:  red
# Node 0 decides:  red
#
# Node : 1 sees red
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  red
# Node 1 decides:  red
#
# Node : 2 sees red
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  red
# Node 2 decides:  red
#
# Node : 3 sees red
# Looking at his neighbours sees {}
# mantained his decision:  red
# Node 3 decides:  red
#
# Node : 4 sees blue
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  blue
# Node 4 decides:  blue
#
# Node : 5 sees blue
# Looking at his neighbours sees { red: 2 }
# it has been influenced towards:  red
# Node 5 decides:  red
#
# Node : 6 sees blue
# Looking at his neighbours sees { red: 2 }
# it has been influenced towards:  red
# Node 6 decides:  red
#
# Node : 7 sees red
# Looking at his neighbours sees { red: 3 }
# mantained his decision:  red
# Node 7 decides:  red
#
# Node : 8 sees red
# Looking at his neighbours sees { red: 2 }
# mantained his decision:  red
# Node 8 decides:  red
#
# Node : 9 sees blue
# Looking at his neighbours sees { red: 4 }
# it has been influenced towards:  red
# Node 9 decides:  red
#
# Node : 10 sees red
# Looking at his neighbours sees { red: 3, blue: 1 }
# mantained his decision:  red
# Node 10 decides:  red
#
# Node : 11 sees red
# Looking at his neighbours sees { red: 3, blue: 1 }
# mantained his decision:  red
# Node 11 decides:  red
#
# Node : 12 sees red
# Looking at his neighbours sees { red: 5 }
# mantained his decision:  red
# Node 12 decides:  red
#
# Node : 13 sees red
# Looking at his neighbours sees { red: 4 }
# mantained his decision:  red
# Node 13 decides:  red
#
# Node : 14 sees red
# Looking at his neighbours sees { red: 4 }
# mantained his decision:  red
# Node 14 decides:  red
#
# Node : 15 sees red
# Looking at his neighbours sees { red: 4, blue: 1 }
# mantained his decision:  red
# Node 15 decides:  red
#
# Node : 16 sees red
# Looking at his neighbours sees { red: 3 }
# mantained his decision:  red
# Node 16 decides:  red
#
# Node : 17 sees red
# Looking at his neighbours sees { red: 8 }
# mantained his decision:  red
# Node 17 decides:  red
#
# Node : 18 sees red
# Looking at his neighbours sees { red: 5, blue: 1 }
# mantained his decision:  red
# Node 18 decides:  red
#
# Node : 19 sees blue
# Looking at his neighbours sees { red: 3 }
# it has been influenced towards:  red
# Node 19 decides:  red
#
# Node : 20 sees red
# Looking at his neighbours sees { red: 7 }
# mantained his decision:  red
# Node 20 decides:  red
#
# Node : 21 sees blue
# Looking at his neighbours sees { red: 7 }
# it has been influenced towards:  red
# Node 21 decides:  red
#
# Node : 22 sees red
# Looking at his neighbours sees { blue: 1, red: 7 }
# mantained his decision:  red
# Node 22 decides:  red
#
# Node : 23 sees red
# Looking at his neighbours sees { blue: 1, red: 6 }
# mantained his decision:  red
# Node 23 decides:  red
#
# Node : 24 sees blue
# Looking at his neighbours sees { red: 8, blue: 1 }
# it has been influenced towards:  red
# Node 24 decides:  red
#
# Node : 25 sees blue
# Looking at his neighbours sees { blue: 1, red: 4 }
# it has been influenced towards:  red
# Node 25 decides:  red
#
# Node : 26 sees blue
# Looking at his neighbours sees { red: 7 }
# it has been influenced towards:  red
# Node 26 decides:  red
#
# Node : 27 sees red
# Looking at his neighbours sees { red: 5 }
# mantained his decision:  red
# Node 27 decides:  red
#
# Node : 28 sees red
# Looking at his neighbours sees { red: 7 }
# mantained his decision:  red
# Node 28 decides:  red
#
# Node : 29 sees red
# Looking at his neighbours sees { red: 5, blue: 1 }
# mantained his decision:  red
# Node 29 decides:  red
#
# Node : 30 sees blue
# Looking at his neighbours sees { red: 10 }
# it has been influenced towards:  red
# Node 30 decides:  red
#
# Node : 31 sees red
# Looking at his neighbours sees { red: 6 }
# mantained his decision:  red
# Node 31 decides:  red
#
# Node : 32 sees red
# Looking at his neighbours sees { red: 12 }
# mantained his decision:  red
# Node 32 decides:  red
#
# Node : 33 sees blue
# Looking at his neighbours sees { red: 10 }
# it has been influenced towards:  red
# Node 33 decides:  red
#
# Node : 34 sees red
# Looking at his neighbours sees { red: 8 }
# mantained his decision:  red
# Node 34 decides:  red
#
# Node : 35 sees blue
# Looking at his neighbours sees { red: 12, blue: 1 }
# it has been influenced towards:  red
# Node 35 decides:  red
#
# Node : 36 sees blue
# Looking at his neighbours sees { red: 7, blue: 1 }
# it has been influenced towards:  red
# Node 36 decides:  red
#
# Node : 37 sees red
# Looking at his neighbours sees { red: 11, blue: 1 }
# mantained his decision:  red
# Node 37 decides:  red
#
# Node : 38 sees red
# Looking at his neighbours sees { red: 14 }
# mantained his decision:  red
# Node 38 decides:  red
#
# Node : 39 sees blue
# Looking at his neighbours sees { red: 15 }
# it has been influenced towards:  red
# Node 39 decides:  red
#
# Node : 40 sees red
# Looking at his neighbours sees { red: 9, blue: 1 }
# mantained his decision:  red
# Node 40 decides:  red
#
# Node : 41 sees blue
# Looking at his neighbours sees { red: 8 }
# it has been influenced towards:  red
# Node 41 decides:  red
#
# Node : 42 sees red
# Looking at his neighbours sees { red: 14 }
# mantained his decision:  red
# Node 42 decides:  red
#
# Node : 43 sees red
# Looking at his neighbours sees { red: 10, blue: 1 }
# mantained his decision:  red
# Node 43 decides:  red
#
# Node : 44 sees red
# Looking at his neighbours sees { red: 14 }
# mantained his decision:  red
# Node 44 decides:  red
#
# Node : 45 sees red
# Looking at his neighbours sees { red: 14 }
# mantained his decision:  red
# Node 45 decides:  red
#
# Node : 46 sees red
# Looking at his neighbours sees { red: 16 }
# mantained his decision:  red
# Node 46 decides:  red
#
# Node : 47 sees red
# Looking at his neighbours sees { red: 12 }
# mantained his decision:  red
# Node 47 decides:  red
#
# Node : 48 sees red
# Looking at his neighbours sees { red: 15 }
# mantained his decision:  red
# Node 48 decides:  red
#
# Node : 49 sees red
# Looking at his neighbours sees { blue: 1, red: 13 }
# mantained his decision:  red
# Node 49 decides:  red
#
# ********* Statistics Summary *********
#
#
# Influencing indexes for node 0 :  []
# Influencing indexes for node 1 :  [ 0 ]
# Influencing indexes for node 2 :  [ 0 ]
# Influencing indexes for node 3 :  []
# Influencing indexes for node 4 :  [ 0 ]
# Influencing indexes for node 5 :  [ 1, 3 ]
# Influencing indexes for node 6 :  [ 0, 1 ]
# Influencing indexes for node 7 :  [ 0, 3, 5 ]
# Influencing indexes for node 8 :  [ 1, 7 ]
# Influencing indexes for node 9 :  [ 0, 1, 2, 8 ]
# Influencing indexes for node 10 :  [ 2, 4, 6, 8 ]
# Influencing indexes for node 11 :  [ 0, 4, 9, 10 ]
# Influencing indexes for node 12 :  [ 1, 2, 8, 9, 10 ]
# Influencing indexes for node 13 :  [ 3, 5, 6, 8 ]
# Influencing indexes for node 14 :  [ 2, 7, 8, 12 ]
# Influencing indexes for node 15 :  [ 0, 3, 4, 8, 13 ]
# Influencing indexes for node 16 :  [ 1, 2, 13 ]
# Influencing indexes for node 17 :  [ 1, 2, 5, 6, 7, 9, 12, 13 ]
# Influencing indexes for node 18 :  [ 0, 1, 4, 6, 13, 14 ]
# Influencing indexes for node 19 :  [ 3, 11, 13 ]
# Influencing indexes for node 20 :  [ 0, 1, 3, 12, 13, 18, 19 ]
# Influencing indexes for node 21 :  [ 1, 3, 7, 11, 17, 19, 20 ]
# Influencing indexes for node 22 :  [ 4, 10, 11, 12, 15, 17, 20, 21 ]
# Influencing indexes for node 23 :  [ 4, 9, 10, 12, 13, 21, 22 ]
# Influencing indexes for node 24 :  [ 2, 4, 5, 7, 11, 13, 17, 19, 22 ]
# Influencing indexes for node 25 :  [ 4, 5, 14, 17, 21 ]
# Influencing indexes for node 26 :  [ 1, 7, 11, 13, 15, 21, 23 ]
# Influencing indexes for node 27 :  [ 0, 10, 14, 18, 26 ]
# Influencing indexes for node 28 :  [ 1, 8, 16, 21, 22, 23, 27 ]
# Influencing indexes for node 29 :  [ 3, 4, 5, 7, 18, 24 ]
# Influencing indexes for node 30 :  [ 1, 8, 9, 10, 18, 19, 23, 26, 27, 29 ]
# Influencing indexes for node 31 :  [ 5, 8, 12, 19, 23, 26 ]
# Influencing indexes for node 32 :  [ 1, 6, 7, 9, 15, 17, 19, 21, 22, 28, 29, 31 ]
# Influencing indexes for node 33 :  [ 1, 3, 6, 11, 12, 14, 17, 19, 24, 26 ]
# Influencing indexes for node 34 :  [ 2, 5, 13, 20, 23, 24, 27, 33 ]
# Influencing indexes for node 35 :  [ 1, 4, 6, 13, 17, 18, 19, 21, 25, 29, 31, 32, 33 ]
# Influencing indexes for node 36 :  [ 1, 4, 10, 11, 12, 19, 25, 33 ]
# Influencing indexes for node 37 :  [ 0, 2, 4, 6, 14, 25, 28, 30, 32, 33, 35, 36 ]
# Influencing indexes for node 38 :  [ 0, 1, 3, 10, 11, 12, 13, 14, 15, 16, 19, 22, 26, 34 ]
# Influencing indexes for node 39 :  [ 1, 3, 6, 8, 9, 12, 14, 17, 18, 24, 25, 26, 27, 30, 37 ]
# Influencing indexes for node 40 :  [ 3, 4, 9, 14, 18, 28, 30, 31, 32, 33 ]
# Influencing indexes for node 41 :  [ 0, 9, 11, 13, 17, 30, 32, 35 ]
# Influencing indexes for node 42 :  [ 11, 17, 19, 20, 21, 22, 26, 27, 28, 30, 32, 34, 35, 41 ]
# Influencing indexes for node 43 :  [ 1, 4, 9, 13, 19, 22, 32, 35, 38, 40, 42 ]
# Influencing indexes for node 44 :  [ 7, 11, 12, 14, 19, 20, 25, 28, 30, 32, 35, 36, 39, 42 ]
# Influencing indexes for node 45 :  [ 3, 8, 9, 12, 15, 19, 23, 24, 26, 28, 29, 37, 42, 44 ]
# Influencing indexes for node 46 :  [ 3, 6, 11, 16, 19, 20, 22, 24, 25, 30, 33, 37, 38, 42, 44, 45 ]
# Influencing indexes for node 47 :  [ 7, 15, 18, 19, 20, 25, 28, 31, 32, 37, 41, 44 ]
# Influencing indexes for node 48 :  [ 5, 6, 9, 12, 14, 18, 20, 22, 23, 27, 28, 31, 35, 40, 45 ]
# Influencing indexes for node 49 :  [ 4, 5, 6, 7, 11, 14, 17, 22, 27, 29, 31, 34, 42, 48 ]
#
# Number of nodes whose opinion didnt matter:  45
# Number of nodes who changed opinion towards the crowd:  14

# %%
df = pd.read_csv(filename, sep=";")
df.head()
# Out:
# Empty DataFrame
# Columns: [Graph type, Number of nodes, Edge chance, Opinions affected by Cascade, Opinions Changed by Cascaderandom, 50, 0.7, 45, 14]
# Index: []
