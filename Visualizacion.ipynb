# %% [markdown]
# # En esta Notebook visualizaremos un grafo resultante

# %% [markdown]
# #### Importamos las librerias necesarias

# %%
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# #### Corremos el programa

# %%
# !node index.js
# Out:
# BLUE URN
# Using Network Graph
# Node : 0 sees blue
# Looking at his neighbours sees {}
# mantained his decision:  blue
# Node 0 decides:  blue
#
# BFS queue:  [ 7, 13, 15, 18, 19 ]
# Node : 7 sees blue
# Looking at his neighbours sees { blue: 1 }
# mantained his decision:  blue
# Node 7 decides:  blue
#
# BFS queue:  [ 13, 15, 18, 19, 2, 16 ]
# Node : 13 sees blue
# Looking at his neighbours sees { blue: 1 }
# mantained his decision:  blue
# Node 13 decides:  blue
#
# BFS queue:  [ 15, 18, 19, 2, 16, 4, 11 ]
# Node : 15 sees red
# Looking at his neighbours sees { blue: 1 }
# mantained his decision:  red
# Node 15 decides:  red
#
# BFS queue:  [ 18, 19, 2, 16, 4, 11, 6, 9, 17 ]
# Node : 18 sees red
# Looking at his neighbours sees { blue: 2 }
# it has been influenced towards:  blue
# Node 18 decides:  blue
#
# BFS queue:  [ 19, 2, 16, 4, 11, 6, 9, 17, 3 ]
# Node : 19 sees red
# Looking at his neighbours sees { blue: 1 }
# mantained his decision:  red
# Node 19 decides:  red
#
# BFS queue:  [ 2, 16, 4, 11, 6, 9, 17, 3, 8 ]
# Node : 2 sees blue
# Looking at his neighbours sees { blue: 2, red: 1 }
# mantained his decision:  blue
# Node 2 decides:  blue
#
# BFS queue:  [ 16, 4, 11, 6, 9, 17, 3, 8, 1 ]
# Node : 16 sees red
# Looking at his neighbours sees { blue: 1 }
# mantained his decision:  red
# Node 16 decides:  red
#
# BFS queue:  [ 4, 11, 6, 9, 17, 3, 8, 1 ]
# Node : 4 sees blue
# Looking at his neighbours sees { blue: 1 }
# mantained his decision:  blue
# Node 4 decides:  blue
#
# BFS queue:  [ 11, 6, 9, 17, 3, 8, 1 ]
# Node : 11 sees blue
# Looking at his neighbours sees { blue: 1, red: 1 }
# mantained his decision:  blue
# Node 11 decides:  blue
#
# BFS queue:  [ 6, 9, 17, 3, 8, 1, 12 ]
# Node : 6 sees blue
# Looking at his neighbours sees { red: 2 }
# it has been influenced towards:  red
# Node 6 decides:  red
#
# BFS queue:  [ 9, 17, 3, 8, 1, 12, 14 ]
# Node : 9 sees blue
# Looking at his neighbours sees { red: 3 }
# it has been influenced towards:  red
# Node 9 decides:  red
#
# BFS queue:  [ 17, 3, 8, 1, 12, 14, 5 ]
# Node : 17 sees blue
# Looking at his neighbours sees { blue: 1, red: 1 }
# mantained his decision:  blue
# Node 17 decides:  blue
#
# BFS queue:  [ 3, 8, 1, 12, 14, 5 ]
# Node : 3 sees blue
# Looking at his neighbours sees { red: 1, blue: 2 }
# mantained his decision:  blue
# Node 3 decides:  blue
#
# BFS queue:  [ 8, 1, 12, 14, 5 ]
# Node : 8 sees blue
# Looking at his neighbours sees { red: 2 }
# it has been influenced towards:  red
# Node 8 decides:  red
#
# BFS queue:  [ 1, 12, 14, 5, 10 ]
# Node : 1 sees blue
# Looking at his neighbours sees { blue: 1, red: 1 }
# mantained his decision:  blue
# Node 1 decides:  blue
#
# BFS queue:  [ 12, 14, 5, 10 ]
# Node : 12 sees blue
# Looking at his neighbours sees { red: 1, blue: 1 }
# mantained his decision:  blue
# Node 12 decides:  blue
#
# BFS queue:  [ 14, 5, 10 ]
# Node : 14 sees red
# Looking at his neighbours sees { red: 2, blue: 1 }
# mantained his decision:  red
# Node 14 decides:  red
#
# BFS queue:  [ 5, 10 ]
# Node : 5 sees blue
# Looking at his neighbours sees { red: 1, blue: 2 }
# mantained his decision:  blue
# Node 5 decides:  blue
#
# BFS queue:  [ 10 ]
# Node : 10 sees red
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  red
# Node 10 decides:  red
#
# ********* Statistics Summary *********
#
#
# Influencing indexes for node 0 :  []
# Influencing indexes for node 1 :  [ 2, 16 ]
# Influencing indexes for node 2 :  [ 7, 13, 15 ]
# Influencing indexes for node 3 :  [ 6, 11, 18 ]
# Influencing indexes for node 4 :  [ 13 ]
# Influencing indexes for node 5 :  [ 9, 12, 17 ]
# Influencing indexes for node 6 :  [ 15, 19 ]
# Influencing indexes for node 7 :  [ 0 ]
# Influencing indexes for node 8 :  [ 6, 19 ]
# Influencing indexes for node 9 :  [ 6, 15, 19 ]
# Influencing indexes for node 10 :  [ 8 ]
# Influencing indexes for node 11 :  [ 13, 15 ]
# Influencing indexes for node 12 :  [ 9, 11 ]
# Influencing indexes for node 13 :  [ 0 ]
# Influencing indexes for node 14 :  [ 6, 8, 12 ]
# Influencing indexes for node 15 :  [ 0 ]
# Influencing indexes for node 16 :  [ 7 ]
# Influencing indexes for node 17 :  [ 4, 15 ]
# Influencing indexes for node 18 :  [ 0, 13 ]
# Influencing indexes for node 19 :  [ 0 ]
#
# Number of nodes whose opinion didnt matter:  8
# Number of nodes who changed opinion towards the crowd:  4

# %% [markdown]
# #### Formateamos el resultado

# %%
f = open("./graphInfo",'r')
[nodes,edges,decisions] = f.read().split(';')
nodes = nodes.split(',')
edges = edges.split('-')
decisions = decisions.split(',')
for i in range(len(nodes)):
    nodes[i] = eval(nodes[i])

for i in range(len(edges)):
    edges[i] = eval(edges[i])
    edges[i] = (edges[i][1],edges[i][0])
    
G = nx.DiGraph()
G.add_nodes_from(nodes)
G.add_edges_from(edges)
plt.figure(figsize=(15,8))
nx.draw_spring(G, node_color=decisions, with_labels=True, font_weight='bold', edge_color='grey',node_size=700)


# Descomentar para dibujar en circulo
# nx.draw_circular(G, node_color=decisions, with_labels=True, font_weight='bold', edge_color='grey',node_size=700)
# plt.savefig("graph.png")

# %% [markdown]
# #### Tenemos alguna duda de vecinos?

# %%
def quienesApuntanA(nodo):
    for i in range(len(edges)):
        if(edges[i][1] == nodo):
            print("Nodo:",edges[i][0])
        
def quienesVenA(nodo):
    for i in range(len(edges)):
        if(edges[i][0] == nodo):
            print("Nodo:",edges[i][1])

# %%
quienesApuntanA(5)
# Out:
# Nodo: 9
# Nodo: 12
# Nodo: 17

# %%
quienesVenA(5)
# Out:
# Nodo: 15
