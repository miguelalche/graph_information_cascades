# %% [markdown]
# # En esta Notebook visualizaremos un grafo resultante

# %% [markdown]
# ###### Para correr cada celda la seleccionamos y presionamos Shift + Enter

# %% [markdown]
# #### Importamos las librerias necesarias

# %%
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# #### Corremos el programa

# %%
# !node index.js
# !node index.js './results.csv' 0.2 'false' 20 './graphInfo' 'line'
# !node index.js './results.csv' 0.2 'false' 20 './graphInfo' 'network' 'bfs'
# !node index.js './results.csv' 0.2 'false' 20 './graphInfo' 'network' 'random'
# Out:
# RED URN
# Using Network Graph
# Node : 0 sees red
# Looking at his neighbours sees {}
# mantained his decision:  red
# Node 0 decides:  red
#
# Node : 1 sees red
# Looking at his neighbours sees {}
# mantained his decision:  red
# Node 1 decides:  red
#
# Node : 2 sees red
# Looking at his neighbours sees {}
# mantained his decision:  red
# Node 2 decides:  red
#
# Node : 3 sees red
# Looking at his neighbours sees {}
# mantained his decision:  red
# Node 3 decides:  red
#
# Node : 4 sees red
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  red
# Node 4 decides:  red
#
# Node : 5 sees blue
# Looking at his neighbours sees {}
# mantained his decision:  blue
# Node 5 decides:  blue
#
# Node : 6 sees red
# Looking at his neighbours sees { red: 2, blue: 1 }
# mantained his decision:  red
# Node 6 decides:  red
#
# Node : 7 sees blue
# Looking at his neighbours sees { blue: 1, red: 1 }
# mantained his decision:  blue
# Node 7 decides:  blue
#
# Node : 8 sees red
# Looking at his neighbours sees { red: 2 }
# mantained his decision:  red
# Node 8 decides:  red
#
# Node : 9 sees blue
# Looking at his neighbours sees { red: 2, blue: 1 }
# mantained his decision:  blue
# Node 9 decides:  blue
#
# Node : 10 sees red
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  red
# Node 10 decides:  red
#
# Node : 11 sees blue
# Looking at his neighbours sees { red: 1 }
# mantained his decision:  blue
# Node 11 decides:  blue
#
# Node : 12 sees blue
# Looking at his neighbours sees { red: 2, blue: 1 }
# mantained his decision:  blue
# Node 12 decides:  blue
#
# Node : 13 sees red
# Looking at his neighbours sees { blue: 1 }
# mantained his decision:  red
# Node 13 decides:  red
#
# Node : 14 sees red
# Looking at his neighbours sees { red: 2 }
# mantained his decision:  red
# Node 14 decides:  red
#
# Node : 15 sees red
# Looking at his neighbours sees { red: 3, blue: 1 }
# mantained his decision:  red
# Node 15 decides:  red
#
# Node : 16 sees blue
# Looking at his neighbours sees { red: 3 }
# it has been influenced towards:  red
# Node 16 decides:  red
#
# Node : 17 sees blue
# Looking at his neighbours sees { red: 2, blue: 2 }
# mantained his decision:  blue
# Node 17 decides:  blue
#
# Node : 18 sees red
# Looking at his neighbours sees { red: 3 }
# mantained his decision:  red
# Node 18 decides:  red
#
# Node : 19 sees red
# Looking at his neighbours sees { red: 2, blue: 1 }
# mantained his decision:  red
# Node 19 decides:  red
#
# ********* Statistics Summary *********
#
#
# Influencing indexes for node 0 :  []
# Influencing indexes for node 1 :  []
# Influencing indexes for node 2 :  []
# Influencing indexes for node 3 :  []
# Influencing indexes for node 4 :  [ 0 ]
# Influencing indexes for node 5 :  []
# Influencing indexes for node 6 :  [ 0, 4, 5 ]
# Influencing indexes for node 7 :  [ 5, 6 ]
# Influencing indexes for node 8 :  [ 2, 4 ]
# Influencing indexes for node 9 :  [ 3, 4, 7 ]
# Influencing indexes for node 10 :  [ 1 ]
# Influencing indexes for node 11 :  [ 2 ]
# Influencing indexes for node 12 :  [ 0, 4, 7 ]
# Influencing indexes for node 13 :  [ 12 ]
# Influencing indexes for node 14 :  [ 1, 10 ]
# Influencing indexes for node 15 :  [ 4, 8, 12, 13 ]
# Influencing indexes for node 16 :  [ 2, 6, 8 ]
# Influencing indexes for node 17 :  [ 0, 5, 12, 15 ]
# Influencing indexes for node 18 :  [ 6, 10, 15 ]
# Influencing indexes for node 19 :  [ 6, 7, 16 ]
#
# Number of nodes whose opinion didnt matter:  10
# Number of nodes who changed opinion towards the crowd:  1

# %% [markdown]
# #### Formateamos el resultado

# %%
f = open("./graphInfo",'r')
[nodes,edges,decisions] = f.read().split(';')
nodes = nodes.split(',')
edges = edges.split('-')
decisions = decisions.split(',')
for i in range(len(nodes)):
    nodes[i] = eval(nodes[i])

for i in range(len(edges)):
    edges[i] = eval(edges[i])
    edges[i] = (edges[i][1],edges[i][0])
    
G = nx.DiGraph()
G.add_nodes_from(nodes)
G.add_edges_from(edges)
plt.figure(figsize=(15,8))
nx.draw_spring(G, node_color=decisions, with_labels=True, font_weight='bold', edge_color='grey',node_size=700)


# Descomentar para dibujar en circulo
# nx.draw_circular(G, node_color=decisions, with_labels=True, font_weight='bold', edge_color='grey',node_size=700)
# plt.savefig("graph.png")

# %% [markdown]
# #### Tenemos alguna duda de vecinos?

# %%
def quienesApuntanA(nodo):
    for i in range(len(edges)):
        if(edges[i][1] == nodo):
            print("Nodo:",edges[i][0])
        
def quienesVenA(nodo):
    for i in range(len(edges)):
        if(edges[i][0] == nodo):
            print("Nodo:",edges[i][1])

# %%
quienesApuntanA(5)
# Out:
# Nodo: 0
# Nodo: 1
# Nodo: 2
# Nodo: 3
# Nodo: 4

# %%
quienesVenA(5)
# Out:
# Nodo: 6
# Nodo: 7
# Nodo: 8
# Nodo: 9
# Nodo: 10
# Nodo: 11
# Nodo: 12
# Nodo: 13
# Nodo: 14
# Nodo: 15
# Nodo: 16
# Nodo: 17
# Nodo: 18
# Nodo: 19
